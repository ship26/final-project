# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('unlabeled_dataset.csv',encoding='utf-8-sig',index_col=0)
df
# Out:
#      press                                            title      date
# 0     한국경제             설 연휴까지 '5인 모임' 금지…'9시 통금'은 1주일 뒤 재논의  20210201
# 1     한국경제                          당·정, 공매도 금지 3개월 연장 '가닥'  20210201
# 2     한국경제                          정상영 명예회장 별세…현대家 창업세대 퇴장  20210201
# 3     한국경제                  수시채용 시대 '진짜 스펙'은 전문성…취업전략 다시 짜라  20210201
# 4     한국경제                          최태원, 2월1일 차기 대한상의 회장 추대  20210201
# ...    ...                                              ...       ...
# 2936  한국경제  [클릭! 한경] '꿈의 직장' 카카오에 무슨 일이…"동료 평가, 서로 불신만 키웠네"  20210227
# 2937  한국경제                 [사설] '임대차法 모델' 독일의 실패, 정부는 보고 있나  20210227
# 2938  한국경제                [사설] 핀테크 부수사업까지 시시콜콜 신고…이런 게 혁신인가  20210227
# 2939  한국경제                   [사설] 이런 '폭주 국회'라면 입법권 박탈이라도 해야  20210227
# 2940  한국경제                    [특파원 칼럼] 美 '코로나 스타' 주지사들의 거짓말  20210227
#
# [2941 rows x 3 columns]

# %%
df['emotion']=np.nan
df
# Out:
#      press                                            title      date  emotion
# 0     한국경제             설 연휴까지 '5인 모임' 금지…'9시 통금'은 1주일 뒤 재논의  20210201      NaN
# 1     한국경제                          당·정, 공매도 금지 3개월 연장 '가닥'  20210201      NaN
# 2     한국경제                          정상영 명예회장 별세…현대家 창업세대 퇴장  20210201      NaN
# 3     한국경제                  수시채용 시대 '진짜 스펙'은 전문성…취업전략 다시 짜라  20210201      NaN
# 4     한국경제                          최태원, 2월1일 차기 대한상의 회장 추대  20210201      NaN
# ...    ...                                              ...       ...      ...
# 2936  한국경제  [클릭! 한경] '꿈의 직장' 카카오에 무슨 일이…"동료 평가, 서로 불신만 키웠네"  20210227      NaN
# 2937  한국경제                 [사설] '임대차法 모델' 독일의 실패, 정부는 보고 있나  20210227      NaN
# 2938  한국경제                [사설] 핀테크 부수사업까지 시시콜콜 신고…이런 게 혁신인가  20210227      NaN
# 2939  한국경제                   [사설] 이런 '폭주 국회'라면 입법권 박탈이라도 해야  20210227      NaN
# 2940  한국경제                    [특파원 칼럼] 美 '코로나 스타' 주지사들의 거짓말  20210227      NaN
#
# [2941 rows x 4 columns]

# %%
for j in range(len(df)):
    test=df['title'][j]
    print(test)
df
# Out:
# 설 연휴까지 '5인 모임' 금지…'9시 통금'은 1주일 뒤 재논의
# 당·정, 공매도 금지 3개월 연장 '가닥'
# 정상영 명예회장 별세…현대家 창업세대 퇴장
# 수시채용 시대 '진짜 스펙'은 전문성…취업전략 다시 짜라
# 최태원, 2월1일 차기 대한상의 회장 추대
# "LG의 미래 이끌 'AI 전사' 3년내 1000명 키우겠다"
# 서로 경쟁하고 가르치고…스스로 진화하는 AI
# [이 아침의 시] % - 김선오(1992~)
# "젊은층 '벼락거지' 만든 집값 대책…당장 거래세부터 낮춰야"
# "학점·토익 높은 '모범생'보다 한 분야 깊게 파는 '마니아' 돼라"
# '文·史·哲'은 무조건 복수전공…제2외국어 구사 유리
# 1957년 이병철 창업주가 직접 선발…고도 성장기 인재확보 핵심 수단
# 삼성이 정기공채 계속 유지하는 까닭
# 채용 규모 줄어든다?…미래 성장산업 추진 기업들은 더 뽑을 듯
# "경력 안보는 공기업 가자"…조폐公 경쟁률 1000대 1 육박
# 與, 네이버·카카오·배달의민족 '정조준'…전방위 '플랫폼 규제법안' 잇달아 발의
# 野, 北원전 총공세…與 "망국적 색깔론"
# 2월 국회 시작부터 '3대 암초'…재보선 앞둔 여야 정면충돌
# 속내 드러낸 이란 "동결자산 풀면 선박 석방 도움"
# 금태섭 출마 선언…안철수에 "1 대 1 경선하자"
# 與, 방통심의위원 '특정인 밀어주기' 의혹
# "내년 대선·지방선거 동시에"…박병석 의장 "1500억 절감"
# 美 헤지펀드들, 철수 않고 반격…게임스톱 '공매도 전쟁' 2라운드
# 국내로 옮겨붙은 '反공매도 운동'…셀트리온이 1호 되나
# 제이크 설리번 백악관 국가안보보좌관 "쿼드는 인도·태평양 정책 토대"
# "한두 번 빅스텝으로 北核 제거는 환상…바이든, 단계적 접근할 것"
# 문재인 대통령-바이든, 이번주 초 통화할 듯
# 韓에 밀린 日조선…CO₂·수소 운반선 '승부수'
# 한때 '빅3'였던 파나소닉, 태양광 패널 사업 접는다
# 토이저러스, 美 마지막 매장도 문 닫는다
# ...

# %%
df.iloc[0,3]=5

# %%
df
# Out:
#      press                                            title      date  emotion
# 0     한국경제             설 연휴까지 '5인 모임' 금지…'9시 통금'은 1주일 뒤 재논의  20210201      5.0
# 1     한국경제                          당·정, 공매도 금지 3개월 연장 '가닥'  20210201      NaN
# 2     한국경제                          정상영 명예회장 별세…현대家 창업세대 퇴장  20210201      NaN
# 3     한국경제                                                5  20210201      NaN
# 4     한국경제                          최태원, 2월1일 차기 대한상의 회장 추대  20210201      NaN
# ...    ...                                              ...       ...      ...
# 2936  한국경제  [클릭! 한경] '꿈의 직장' 카카오에 무슨 일이…"동료 평가, 서로 불신만 키웠네"  20210227      NaN
# 2937  한국경제                 [사설] '임대차法 모델' 독일의 실패, 정부는 보고 있나  20210227      NaN
# 2938  한국경제                [사설] 핀테크 부수사업까지 시시콜콜 신고…이런 게 혁신인가  20210227      NaN
# 2939  한국경제                   [사설] 이런 '폭주 국회'라면 입법권 박탈이라도 해야  20210227      NaN
# 2940  한국경제                    [특파원 칼럼] 美 '코로나 스타' 주지사들의 거짓말  20210227      NaN
#
# [2941 rows x 4 columns]
