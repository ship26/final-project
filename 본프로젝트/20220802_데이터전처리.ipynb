# %%
import pandas as pd
import numpy as np

# %%
data1=pd.read_csv('data/KOSDAQ.csv',encoding='utf-8-sig',index_col=0)
data2=pd.read_csv('data/Merge_common_percent.csv',encoding='utf-8-sig',index_col=0)
data3=pd.read_csv('data/finance_percent_3.csv',encoding='utf-8-sig',index_col=0)

# %% [markdown]
# data1=pd.read_csv('data/USD.csv',encoding='utf-8-sig',index_col=0)

# %%
data2.tail(20)
# Out:
#          date press  0_percent  1_percent  2_percent   뉴스개수
# 319  20220615  일반언론   0.278662   0.119427   0.601911  628.0
# 320  20220616  일반언론   0.299546   0.102874   0.597579  661.0
# 321  20220617  일반언론   0.310089   0.089021   0.600890  674.0
# 322  20220618  일반언론   0.353881   0.075342   0.570776  438.0
# 323  20220620  일반언론   0.286424   0.122517   0.591060  604.0
# 324  20220621  일반언론   0.321752   0.107251   0.570997  662.0
# 325  20220622  일반언론   0.269865   0.125937   0.604198  667.0
# 326  20220623  일반언론   0.292023   0.123932   0.584046  702.0
# 327  20220624  일반언론   0.307229   0.103916   0.588855  664.0
# 328  20220625  일반언론   0.319540   0.087356   0.593103  435.0
# 329  20220627  일반언론   0.301303   0.079805   0.618893  614.0
# 330  20220628  일반언론   0.301634   0.093611   0.604755  673.0
# 331  20220629  일반언론   0.302115   0.108761   0.589124  662.0
# 332  20220630  일반언론   0.281553   0.118123   0.600324  618.0
# 333  20210920  일반언론   0.250000   0.083333   0.666667   12.0
# ...

# %%
data3.tail(20)
# Out:
#      press      date  0_percent  1_percent  2_percent  뉴스개수
# 371  네이버금융  20220611   0.526316   0.315789   0.157895    19
# 372  네이버금융  20220612   0.333333   0.666667   0.000000     3
# 373  네이버금융  20220613   0.285714   0.000000   0.714286     7
# 374  네이버금융  20220614   0.500000   0.250000   0.250000    12
# 375  네이버금융  20220615   0.300000   0.500000   0.200000    20
# 376  네이버금융  20220616   0.263158   0.421053   0.315789    19
# 377  네이버금융  20220617   0.500000   0.222222   0.277778    18
# 378  네이버금융  20220618   0.473684   0.263158   0.263158    19
# 379  네이버금융  20220619   1.000000   0.000000   0.000000     3
# 380  네이버금융  20220620   0.000000   0.571429   0.428571     7
# 381  네이버금융  20220621   0.750000   0.166667   0.083333    12
# 382  네이버금융  20220622   0.300000   0.500000   0.200000    20
# 383  네이버금융  20220623   0.473684   0.473684   0.052632    19
# 384  네이버금융  20220624   0.700000   0.150000   0.150000    20
# 385  네이버금융  20220625   0.470588   0.470588   0.058824    17
# ...

# %%
merge_data1=pd.merge(data2,data3,left_on='date',right_on='date',how='right')
merge_data1.head(20)
# Out:
#         date press_x  0_percent_x  1_percent_x  2_percent_x  뉴스개수_x press_y  \
# 0   20210601    일반언론     0.270270     0.102703     0.627027   740.0   네이버금융
# 1   20210602    일반언론     0.253666     0.123167     0.623167   682.0   네이버금융
# 2   20210603    일반언론     0.259467     0.099579     0.640954   713.0   네이버금융
# 3   20210604    일반언론     0.256233     0.126039     0.617729   722.0   네이버금융
# 4   20210605    일반언론     0.324138     0.094253     0.581609   435.0   네이버금융
# 5   20210606     NaN          NaN          NaN          NaN     NaN   네이버금융
# 6   20210607    일반언론     0.269919     0.102439     0.627642   615.0   네이버금융
# 7   20210608    일반언론     0.262411     0.114894     0.622695   705.0   네이버금융
# 8   20210609    일반언론     0.291086     0.119777     0.589136   718.0   네이버금융
# 9   20210610    일반언론     0.267936     0.131772     0.600293   683.0   네이버금융
# 10  20210611    일반언론     0.232955     0.106534     0.660511   704.0   네이버금융
# ...

# %%
merge_data1.rename(columns={'press_x':'press_c',
                   '0_percent_x':'0_percent_c',
                    '1_percent_x':'1_percent_c',
                    '2_percent_x':'2_percent_c',
                    '뉴스개수_x':'뉴스개수_c',
                    'press_y':'press_f',
                    '0_percent_y':'0_percent_f',
                    '1_percent_y':'1_percent_f',
                    '2_percent_y':'2_percent_f',
                    '뉴스개수_y':'뉴스개수_f',
                   },inplace=True)
merge_data1
# Out:
#          date press_c  0_percent_c  1_percent_c  2_percent_c  뉴스개수_c press_f  \
# 0    20210601    일반언론     0.270270     0.102703     0.627027   740.0   네이버금융
# 1    20210602    일반언론     0.253666     0.123167     0.623167   682.0   네이버금융
# 2    20210603    일반언론     0.259467     0.099579     0.640954   713.0   네이버금융
# 3    20210604    일반언론     0.256233     0.126039     0.617729   722.0   네이버금융
# 4    20210605    일반언론     0.324138     0.094253     0.581609   435.0   네이버금융
# ..        ...     ...          ...          ...          ...     ...     ...
# 386  20220626     NaN          NaN          NaN          NaN     NaN   네이버금융
# 387  20220627    일반언론     0.301303     0.079805     0.618893   614.0   네이버금융
# 388  20220628    일반언론     0.301634     0.093611     0.604755   673.0   네이버금융
# 389  20220629    일반언론     0.302115     0.108761     0.589124   662.0   네이버금융
# 390  20220630    일반언론     0.281553     0.118123     0.600324   618.0   네이버금융
#
# ...

# %%
data1
# Out:
#               Open    High     Low   Close         거래량          거래대금  \
# Date
# 2021-06-01  982.25  984.61  979.13  984.59  1779134671  9.307170e+12
# 2021-06-02  985.50  986.00  977.74  981.10  1608837586  9.639650e+12
# 2021-06-03  981.52  992.01  981.52  990.19  1704638309  8.903650e+12
# 2021-06-04  990.16  990.16  983.02  987.58  2145264098  9.881300e+12
# 2021-06-07  989.16  993.06  982.14  985.86  1954562972  9.593190e+12
# ...            ...     ...     ...     ...         ...           ...
# 2022-07-22  796.58  800.65  789.73  789.75   892760423  6.131000e+12
# 2022-07-25  787.71  791.25  783.78  789.69   871219511  5.494820e+12
# 2022-07-26  788.76  791.01  786.46  789.93   841385906  5.373790e+12
# 2022-07-27  789.61  795.81  788.29  795.70   678540939  5.162360e+12
# 2022-07-28  802.50  805.20  796.48  798.32   737057966  5.915930e+12
#
#                   상장시가총액    Change
# Date
# 2021-06-01  4.101990e+14       NaN
# 2021-06-02  4.086270e+14 -0.354462
# ...

# %%
data1['date']=data1.index
data1=data1.reset_index(drop=True)
data1
# Out:
#        Open    High     Low   Close         거래량          거래대금        상장시가총액  \
# 0    982.25  984.61  979.13  984.59  1779134671  9.307170e+12  4.101990e+14
# 1    985.50  986.00  977.74  981.10  1608837586  9.639650e+12  4.086270e+14
# 2    981.52  992.01  981.52  990.19  1704638309  8.903650e+12  4.126240e+14
# 3    990.16  990.16  983.02  987.58  2145264098  9.881300e+12  4.116270e+14
# 4    989.16  993.06  982.14  985.86  1954562972  9.593190e+12  4.109410e+14
# ..      ...     ...     ...     ...         ...           ...           ...
# 283  796.58  800.65  789.73  789.75   892760423  6.131000e+12  3.553840e+14
# 284  787.71  791.25  783.78  789.69   871219511  5.494820e+12  3.551450e+14
# 285  788.76  791.01  786.46  789.93   841385906  5.373790e+12  3.551740e+14
# 286  789.61  795.81  788.29  795.70   678540939  5.162360e+12  3.576730e+14
# 287  802.50  805.20  796.48  798.32   737057966  5.915930e+12  3.601620e+14
#
#        Change        date
# 0         NaN  2021-06-01
# ...

# %%
def preprocess(x):
    x=x.replace('-','')
    return int(x)

data1['date']=data1['date'].apply(preprocess)
data1
# Out:
#        Open    High     Low   Close         거래량          거래대금        상장시가총액  \
# 0    982.25  984.61  979.13  984.59  1779134671  9.307170e+12  4.101990e+14
# 1    985.50  986.00  977.74  981.10  1608837586  9.639650e+12  4.086270e+14
# 2    981.52  992.01  981.52  990.19  1704638309  8.903650e+12  4.126240e+14
# 3    990.16  990.16  983.02  987.58  2145264098  9.881300e+12  4.116270e+14
# 4    989.16  993.06  982.14  985.86  1954562972  9.593190e+12  4.109410e+14
# ..      ...     ...     ...     ...         ...           ...           ...
# 283  796.58  800.65  789.73  789.75   892760423  6.131000e+12  3.553840e+14
# 284  787.71  791.25  783.78  789.69   871219511  5.494820e+12  3.551450e+14
# 285  788.76  791.01  786.46  789.93   841385906  5.373790e+12  3.551740e+14
# 286  789.61  795.81  788.29  795.70   678540939  5.162360e+12  3.576730e+14
# 287  802.50  805.20  796.48  798.32   737057966  5.915930e+12  3.601620e+14
#
#        Change      date
# 0         NaN  20210601
# ...

# %%
data1=data1[:-20]
data1
# Out:
#        Open    High     Low   Close         거래량          거래대금        상장시가총액  \
# 0    982.25  984.61  979.13  984.59  1779134671  9.307170e+12  4.101990e+14
# 1    985.50  986.00  977.74  981.10  1608837586  9.639650e+12  4.086270e+14
# 2    981.52  992.01  981.52  990.19  1704638309  8.903650e+12  4.126240e+14
# 3    990.16  990.16  983.02  987.58  2145264098  9.881300e+12  4.116270e+14
# 4    989.16  993.06  982.14  985.86  1954562972  9.593190e+12  4.109410e+14
# ..      ...     ...     ...     ...         ...           ...           ...
# 263  719.47  750.41  719.47  750.30   837119070  6.287370e+12  3.346940e+14
# 264  758.00  774.57  754.62  770.60   893324155  6.699470e+12  3.345460e+14
# 265  770.69  774.80  759.83  769.51   978286886  6.455440e+12  3.346840e+14
# 266  759.21  765.79  753.32  762.35   819568049  5.970950e+12  3.316670e+14
# 267  762.45  762.45  744.24  745.44   910028517  6.318520e+12  3.251640e+14
#
#        Change      date
# 0         NaN  20210601
# ...

# %%
k1=data1.date.unique()

# %% [markdown]
# data1.date.unique()

# %%
k2=merge_data1.date.unique()

# %%
merge_data1
# Out:
#          date press_c  0_percent_c  1_percent_c  2_percent_c  뉴스개수_c press_f  \
# 0    20210601    일반언론     0.270270     0.102703     0.627027   740.0   네이버금융
# 1    20210602    일반언론     0.253666     0.123167     0.623167   682.0   네이버금융
# 2    20210603    일반언론     0.259467     0.099579     0.640954   713.0   네이버금융
# 3    20210604    일반언론     0.256233     0.126039     0.617729   722.0   네이버금융
# 4    20210605    일반언론     0.324138     0.094253     0.581609   435.0   네이버금융
# ..        ...     ...          ...          ...          ...     ...     ...
# 386  20220626     NaN          NaN          NaN          NaN     NaN   네이버금융
# 387  20220627    일반언론     0.301303     0.079805     0.618893   614.0   네이버금융
# 388  20220628    일반언론     0.301634     0.093611     0.604755   673.0   네이버금융
# 389  20220629    일반언론     0.302115     0.108761     0.589124   662.0   네이버금융
# 390  20220630    일반언론     0.281553     0.118123     0.600324   618.0   네이버금융
#
# ...

# %%
type(k1[0])
# Out:
# numpy.int64

# %%
count=0
이상치=0
for i in k1:
    if i in k2:
        count+=1
    else:
        이상치 +=1
        print(i)
print(count, 이상치)
# Out:
# 268 0

# %%
k1  #장시장
# Out:
# array([20210601, 20210602, 20210603, 20210604, 20210607, 20210608,
#        20210609, 20210610, 20210611, 20210614, 20210615, 20210616,
#        20210617, 20210618, 20210621, 20210622, 20210623, 20210624,
#        20210625, 20210628, 20210629, 20210630, 20210701, 20210702,
#        20210705, 20210706, 20210707, 20210708, 20210709, 20210712,
#        20210713, 20210714, 20210715, 20210716, 20210719, 20210720,
#        20210721, 20210722, 20210723, 20210726, 20210727, 20210728,
#        20210729, 20210730, 20210802, 20210803, 20210804, 20210805,
#        20210806, 20210809, 20210810, 20210811, 20210812, 20210813,
#        20210817, 20210818, 20210819, 20210820, 20210823, 20210824,
#        20210825, 20210826, 20210827, 20210830, 20210831, 20210901,
#        20210902, 20210903, 20210906, 20210907, 20210908, 20210909,
#        20210910, 20210913, 20210914, 20210915, 20210916, 20210917,
#        20210923, 20210924, 20210927, 20210928, 20210929, 20210930,
# ...

# %%
k2  #언론 날짜
# Out:
# array([20210601, 20210602, 20210603, 20210604, 20210605, 20210606,
#        20210607, 20210608, 20210609, 20210610, 20210611, 20210612,
#        20210613, 20210614, 20210615, 20210616, 20210617, 20210618,
#        20210619, 20210620, 20210621, 20210622, 20210623, 20210624,
#        20210625, 20210626, 20210627, 20210628, 20210629, 20210630,
#        20210701, 20210702, 20210703, 20210704, 20210705, 20210706,
#        20210707, 20210708, 20210709, 20210710, 20210711, 20210712,
#        20210713, 20210714, 20210715, 20210716, 20210717, 20210718,
#        20210719, 20210720, 20210721, 20210722, 20210723, 20210724,
#        20210725, 20210726, 20210727, 20210728, 20210729, 20210730,
#        20210731, 20210801, 20210802, 20210803, 20210804, 20210805,
#        20210806, 20210807, 20210808, 20210809, 20210810, 20210811,
#        20210812, 20210813, 20210814, 20210815, 20210816, 20210817,
#        20210818, 20210819, 20210820, 20210821, 20210822, 20210823,
# ...

# %%
data3.head(10)
# Out:
#    press      date  0_percent  1_percent  2_percent  뉴스개수
# 0  네이버금융  20210601   0.357143   0.500000   0.142857    14
# 1  네이버금융  20210602   0.500000   0.388889   0.111111    18
# 2  네이버금융  20210603   0.157895   0.736842   0.105263    19
# 3  네이버금융  20210604   0.789474   0.105263   0.105263    19
# 4  네이버금융  20210605   0.000000   1.000000   0.000000     2
# 5  네이버금융  20210606   0.250000   0.250000   0.500000     8
# 6  네이버금융  20210607   0.615385   0.384615   0.000000    13
# 7  네이버금융  20210608   0.550000   0.100000   0.350000    20
# 8  네이버금융  20210609   0.625000   0.187500   0.187500    16
# 9  네이버금융  20210610   0.631579   0.052632   0.315789    19

# %%
merge_data1.head(20)
# Out:
#         date press_c  0_percent_c  1_percent_c  2_percent_c  뉴스개수_c press_f  \
# 0   20210601    일반언론     0.270270     0.102703     0.627027   740.0   네이버금융
# 1   20210602    일반언론     0.253666     0.123167     0.623167   682.0   네이버금융
# 2   20210603    일반언론     0.259467     0.099579     0.640954   713.0   네이버금융
# 3   20210604    일반언론     0.256233     0.126039     0.617729   722.0   네이버금융
# 4   20210605    일반언론     0.324138     0.094253     0.581609   435.0   네이버금융
# 5   20210606     NaN          NaN          NaN          NaN     NaN   네이버금융
# 6   20210607    일반언론     0.269919     0.102439     0.627642   615.0   네이버금융
# 7   20210608    일반언론     0.262411     0.114894     0.622695   705.0   네이버금융
# 8   20210609    일반언론     0.291086     0.119777     0.589136   718.0   네이버금융
# 9   20210610    일반언론     0.267936     0.131772     0.600293   683.0   네이버금융
# 10  20210611    일반언론     0.232955     0.106534     0.660511   704.0   네이버금융
# ...

# %%
import math

merge_data1
merge_data1['부정_c']=round(merge_data1['뉴스개수_c']*merge_data1['0_percent_c'])
merge_data1['긍정_c']=round(merge_data1['뉴스개수_c']*merge_data1['1_percent_c'])
merge_data1['중립_c']=round(merge_data1['뉴스개수_c']*merge_data1['2_percent_c'])
merge_data1['부정_f']=round(merge_data1['뉴스개수_f']*merge_data1['0_percent_f'])
merge_data1['긍정_f']=round(merge_data1['뉴스개수_f']*merge_data1['1_percent_f'])
merge_data1['중립_f']=round(merge_data1['뉴스개수_f']*merge_data1['2_percent_f'])
merge_data1
# Out:
#          date press_c  0_percent_c  1_percent_c  2_percent_c  뉴스개수_c press_f  \
# 0    20210601    일반언론     0.270270     0.102703     0.627027   740.0   네이버금융
# 1    20210602    일반언론     0.253666     0.123167     0.623167   682.0   네이버금융
# 2    20210603    일반언론     0.259467     0.099579     0.640954   713.0   네이버금융
# 3    20210604    일반언론     0.256233     0.126039     0.617729   722.0   네이버금융
# 4    20210605    일반언론     0.324138     0.094253     0.581609   435.0   네이버금융
# ..        ...     ...          ...          ...          ...     ...     ...
# 386  20220626     NaN          NaN          NaN          NaN     NaN   네이버금융
# 387  20220627    일반언론     0.301303     0.079805     0.618893   614.0   네이버금융
# 388  20220628    일반언론     0.301634     0.093611     0.604755   673.0   네이버금융
# 389  20220629    일반언론     0.302115     0.108761     0.589124   662.0   네이버금융
# 390  20220630    일반언론     0.281553     0.118123     0.600324   618.0   네이버금융
#
# ...

# %%
일요일=merge_data1[merge_data1['press_c'].isnull()].index
토요일=일요일-1
월요일=일요일+1
월요일

print(len(토요일),len(일요일),len(월요일))
# Out:
# 54 54 54

# %%
DF=merge_data1.copy()
DF.head(50)
# Out:
#         date press_c  0_percent_c  1_percent_c  2_percent_c  뉴스개수_c press_f  \
# 0   20210601    일반언론     0.270270     0.102703     0.627027   740.0   네이버금융
# 1   20210602    일반언론     0.253666     0.123167     0.623167   682.0   네이버금융
# 2   20210603    일반언론     0.259467     0.099579     0.640954   713.0   네이버금융
# 3   20210604    일반언론     0.256233     0.126039     0.617729   722.0   네이버금융
# 4   20210605    일반언론     0.324138     0.094253     0.581609   435.0   네이버금융
# 5   20210606     NaN          NaN          NaN          NaN     NaN   네이버금융
# 6   20210607    일반언론     0.269919     0.102439     0.627642   615.0   네이버금융
# 7   20210608    일반언론     0.262411     0.114894     0.622695   705.0   네이버금융
# 8   20210609    일반언론     0.291086     0.119777     0.589136   718.0   네이버금융
# 9   20210610    일반언론     0.267936     0.131772     0.600293   683.0   네이버금융
# 10  20210611    일반언론     0.232955     0.106534     0.660511   704.0   네이버금융
# ...

# %%
월요일일반뉴스개수=merge_data1.iloc[월요일]['뉴스개수_c'].reset_index(drop=True)
토요일일반뉴스개수=merge_data1.iloc[토요일]['뉴스개수_c'].reset_index(drop=True)
월요일일반뉴스개수=월요일일반뉴스개수+토요일일반뉴스개수
월요일일반뉴스개수.values
# Out:
# array([1050., 1078., 1054., 1098., 1049., 1093., 1112., 1071.,  983.,
#        1028.,  959., 1046., 1126., 1049., 1026.,  442., 1081., 1113.,
#         927., 1069., 1041., 1053., 1038., 1047., 1045., 1089., 1070.,
#        1037., 1071., 1037., 1031., 1047., 1061.,  449., 1033., 1075.,
#        1042., 1078., 1042., 1056., 1074., 1087., 1048., 1036., 1063.,
#         996., 1002., 1047., 1092., 1076.,  920., 1043., 1042., 1049.])

# %%
월요일일반부정개수=merge_data1.iloc[월요일]['부정_c'].reset_index(drop=True)
토요일일반부정개수=merge_data1.iloc[토요일]['부정_c'].reset_index(drop=True)
월요일일반부정개수=월요일일반부정개수+토요일일반부정개수

월요일일반긍정개수=merge_data1.iloc[월요일]['긍정_c'].reset_index(drop=True)
토요일일반긍정개수=merge_data1.iloc[토요일]['긍정_c'].reset_index(drop=True)
월요일일반긍정개수=월요일일반긍정개수+토요일일반긍정개수

월요일일반중립개수=merge_data1.iloc[월요일]['중립_c'].reset_index(drop=True)
토요일일반중립개수=merge_data1.iloc[토요일]['중립_c'].reset_index(drop=True)
월요일일반중립개수=월요일일반중립개수+토요일일반중립개수

# %%
DF.loc[월요일, '뉴스개수_c'] = 월요일일반뉴스개수.values
DF.loc[월요일, '부정_c'] = 월요일일반부정개수.values
DF.loc[월요일, '긍정_c'] = 월요일일반긍정개수.values
DF.loc[월요일, '중립_c'] = 월요일일반중립개수.values

DF.head(20)
# Out:
#         date press_c  0_percent_c  1_percent_c  2_percent_c  뉴스개수_c press_f  \
# 0   20210601    일반언론     0.270270     0.102703     0.627027   740.0   네이버금융
# 1   20210602    일반언론     0.253666     0.123167     0.623167   682.0   네이버금융
# 2   20210603    일반언론     0.259467     0.099579     0.640954   713.0   네이버금융
# 3   20210604    일반언론     0.256233     0.126039     0.617729   722.0   네이버금융
# 4   20210605    일반언론     0.324138     0.094253     0.581609   435.0   네이버금융
# 5   20210606     NaN          NaN          NaN          NaN     NaN   네이버금융
# 6   20210607    일반언론     0.269919     0.102439     0.627642  1050.0   네이버금융
# 7   20210608    일반언론     0.262411     0.114894     0.622695   705.0   네이버금융
# 8   20210609    일반언론     0.291086     0.119777     0.589136   718.0   네이버금융
# 9   20210610    일반언론     0.267936     0.131772     0.600293   683.0   네이버금융
# 10  20210611    일반언론     0.232955     0.106534     0.660511   704.0   네이버금융
# ...

# %%
월요일금융뉴스개수=merge_data1.iloc[월요일]['뉴스개수_f'].reset_index(drop=True)
토요일금융뉴스개수=merge_data1.iloc[토요일]['뉴스개수_f'].reset_index(drop=True)
일요일금융뉴스개수=merge_data1.iloc[일요일]['뉴스개수_f'].reset_index(drop=True)
월요일금융뉴스개수=월요일금융뉴스개수+토요일금융뉴스개수+일요일금융뉴스개수
월요일금융뉴스개수.values
# Out:
# array([23, 22, 22, 19, 21, 20, 21, 21, 21, 20,  8, 20, 22, 22, 18,  7, 16,
#        20,  9, 19, 18, 21, 19, 22, 18, 18, 20, 18, 18, 17, 30, 28, 28, 25,
#        28,  9, 28, 25, 29, 31, 30, 28, 27, 28, 28, 28, 28, 27, 28, 27, 29,
#        29, 29, 24], dtype=int64)

# %%
월요일금융부정개수=merge_data1.iloc[월요일]['부정_f'].reset_index(drop=True)
토요일금융부정개수=merge_data1.iloc[토요일]['부정_f'].reset_index(drop=True)
일요일금융부정개수=merge_data1.iloc[일요일]['부정_f'].reset_index(drop=True)
월요일금융부정개수=월요일금융부정개수+토요일금융부정개수+일요일금융부정개수

월요일금융긍정개수=merge_data1.iloc[월요일]['긍정_f'].reset_index(drop=True)
토요일금융긍정개수=merge_data1.iloc[토요일]['긍정_f'].reset_index(drop=True)
일요일금융긍정개수=merge_data1.iloc[일요일]['긍정_f'].reset_index(drop=True)
월요일금융긍정개수=월요일금융긍정개수+토요일금융긍정개수+일요일금융긍정개수

월요일금융중립개수=merge_data1.iloc[월요일]['중립_f'].reset_index(drop=True)
토요일금융중립개수=merge_data1.iloc[토요일]['중립_f'].reset_index(drop=True)
일요일금융중립개수=merge_data1.iloc[일요일]['중립_f'].reset_index(drop=True)
월요일금융중립개수=월요일금융중립개수+토요일금융중립개수+일요일금융중립개수

# %%
DF.loc[월요일, '뉴스개수_f'] = 월요일금융뉴스개수.values
DF.loc[월요일, '부정_f'] = 월요일금융부정개수.values
DF.loc[월요일, '긍정_f'] = 월요일금융긍정개수.values
DF.loc[월요일, '중립_f'] = 월요일금융중립개수.values

DF.head(20)
# Out:
#         date press_c  0_percent_c  1_percent_c  2_percent_c  뉴스개수_c press_f  \
# 0   20210601    일반언론     0.270270     0.102703     0.627027   740.0   네이버금융
# 1   20210602    일반언론     0.253666     0.123167     0.623167   682.0   네이버금융
# 2   20210603    일반언론     0.259467     0.099579     0.640954   713.0   네이버금융
# 3   20210604    일반언론     0.256233     0.126039     0.617729   722.0   네이버금융
# 4   20210605    일반언론     0.324138     0.094253     0.581609   435.0   네이버금융
# 5   20210606     NaN          NaN          NaN          NaN     NaN   네이버금융
# 6   20210607    일반언론     0.269919     0.102439     0.627642  1050.0   네이버금융
# 7   20210608    일반언론     0.262411     0.114894     0.622695   705.0   네이버금융
# 8   20210609    일반언론     0.291086     0.119777     0.589136   718.0   네이버금융
# 9   20210610    일반언론     0.267936     0.131772     0.600293   683.0   네이버금융
# 10  20210611    일반언론     0.232955     0.106534     0.660511   704.0   네이버금융
# ...

# %%
DF['0_percent_c']=DF['부정_c']/DF['뉴스개수_c']
DF['1_percent_c']=DF['긍정_c']/DF['뉴스개수_c']
DF['2_percent_c']=DF['중립_c']/DF['뉴스개수_c']
DF.head(20)
# Out:
#         date press_c  0_percent_c  1_percent_c  2_percent_c  뉴스개수_c press_f  \
# 0   20210601    일반언론     0.270270     0.102703     0.627027   740.0   네이버금융
# 1   20210602    일반언론     0.253666     0.123167     0.623167   682.0   네이버금융
# 2   20210603    일반언론     0.259467     0.099579     0.640954   713.0   네이버금융
# 3   20210604    일반언론     0.256233     0.126039     0.617729   722.0   네이버금융
# 4   20210605    일반언론     0.324138     0.094253     0.581609   435.0   네이버금융
# 5   20210606     NaN          NaN          NaN          NaN     NaN   네이버금융
# 6   20210607    일반언론     0.292381     0.099048     0.608571  1050.0   네이버금융
# 7   20210608    일반언론     0.262411     0.114894     0.622695   705.0   네이버금융
# 8   20210609    일반언론     0.291086     0.119777     0.589136   718.0   네이버금융
# 9   20210610    일반언론     0.267936     0.131772     0.600293   683.0   네이버금융
# 10  20210611    일반언론     0.232955     0.106534     0.660511   704.0   네이버금융
# ...

# %%
DF['0_percent_f']=DF['부정_f']/DF['뉴스개수_f']
DF['1_percent_f']=DF['긍정_f']/DF['뉴스개수_f']
DF['2_percent_f']=DF['중립_f']/DF['뉴스개수_f']
DF.head(20)
# Out:
#         date press_c  0_percent_c  1_percent_c  2_percent_c  뉴스개수_c press_f  \
# 0   20210601    일반언론     0.270270     0.102703     0.627027   740.0   네이버금융
# 1   20210602    일반언론     0.253666     0.123167     0.623167   682.0   네이버금융
# 2   20210603    일반언론     0.259467     0.099579     0.640954   713.0   네이버금융
# 3   20210604    일반언론     0.256233     0.126039     0.617729   722.0   네이버금융
# 4   20210605    일반언론     0.324138     0.094253     0.581609   435.0   네이버금융
# 5   20210606     NaN          NaN          NaN          NaN     NaN   네이버금융
# 6   20210607    일반언론     0.292381     0.099048     0.608571  1050.0   네이버금융
# 7   20210608    일반언론     0.262411     0.114894     0.622695   705.0   네이버금융
# 8   20210609    일반언론     0.291086     0.119777     0.589136   718.0   네이버금융
# 9   20210610    일반언론     0.267936     0.131772     0.600293   683.0   네이버금융
# 10  20210611    일반언론     0.232955     0.106534     0.660511   704.0   네이버금융
# ...

# %%
DF.drop(토요일,inplace=True)
DF.head(20)
# Out:
#         date press_c  0_percent_c  1_percent_c  2_percent_c  뉴스개수_c press_f  \
# 0   20210601    일반언론     0.270270     0.102703     0.627027   740.0   네이버금융
# 1   20210602    일반언론     0.253666     0.123167     0.623167   682.0   네이버금융
# 2   20210603    일반언론     0.259467     0.099579     0.640954   713.0   네이버금융
# 3   20210604    일반언론     0.256233     0.126039     0.617729   722.0   네이버금융
# 5   20210606     NaN          NaN          NaN          NaN     NaN   네이버금융
# 6   20210607    일반언론     0.292381     0.099048     0.608571  1050.0   네이버금융
# 7   20210608    일반언론     0.262411     0.114894     0.622695   705.0   네이버금융
# 8   20210609    일반언론     0.291086     0.119777     0.589136   718.0   네이버금융
# 9   20210610    일반언론     0.267936     0.131772     0.600293   683.0   네이버금융
# 10  20210611    일반언론     0.232955     0.106534     0.660511   704.0   네이버금융
# 12  20210613     NaN          NaN          NaN          NaN     NaN   네이버금융
# ...

# %%
DF.drop(일요일,inplace=True)
DF.head(20)
# Out:
#         date press_c  0_percent_c  1_percent_c  2_percent_c  뉴스개수_c press_f  \
# 0   20210601    일반언론     0.270270     0.102703     0.627027   740.0   네이버금융
# 1   20210602    일반언론     0.253666     0.123167     0.623167   682.0   네이버금융
# 2   20210603    일반언론     0.259467     0.099579     0.640954   713.0   네이버금융
# 3   20210604    일반언론     0.256233     0.126039     0.617729   722.0   네이버금융
# 6   20210607    일반언론     0.292381     0.099048     0.608571  1050.0   네이버금융
# 7   20210608    일반언론     0.262411     0.114894     0.622695   705.0   네이버금융
# 8   20210609    일반언론     0.291086     0.119777     0.589136   718.0   네이버금융
# 9   20210610    일반언론     0.267936     0.131772     0.600293   683.0   네이버금융
# 10  20210611    일반언론     0.232955     0.106534     0.660511   704.0   네이버금융
# 13  20210614    일반언론     0.275510     0.093692     0.630798  1078.0   네이버금융
# 14  20210615    일반언론     0.217893     0.103896     0.678211   693.0   네이버금융
# ...

# %%
data1
# Out:
#        Open    High     Low   Close         거래량          거래대금        상장시가총액  \
# 0    982.25  984.61  979.13  984.59  1779134671  9.307170e+12  4.101990e+14
# 1    985.50  986.00  977.74  981.10  1608837586  9.639650e+12  4.086270e+14
# 2    981.52  992.01  981.52  990.19  1704638309  8.903650e+12  4.126240e+14
# 3    990.16  990.16  983.02  987.58  2145264098  9.881300e+12  4.116270e+14
# 4    989.16  993.06  982.14  985.86  1954562972  9.593190e+12  4.109410e+14
# ..      ...     ...     ...     ...         ...           ...           ...
# 263  719.47  750.41  719.47  750.30   837119070  6.287370e+12  3.346940e+14
# 264  758.00  774.57  754.62  770.60   893324155  6.699470e+12  3.345460e+14
# 265  770.69  774.80  759.83  769.51   978286886  6.455440e+12  3.346840e+14
# 266  759.21  765.79  753.32  762.35   819568049  5.970950e+12  3.316670e+14
# 267  762.45  762.45  744.24  745.44   910028517  6.318520e+12  3.251640e+14
#
#        Change      date
# 0         NaN  20210601
# ...

# %%
MERGE_DF=pd.merge(data1,DF,left_on='date',right_on='date',how='left')
MERGE_DF
# Out:
#        Open    High     Low   Close         거래량          거래대금        상장시가총액  \
# 0    982.25  984.61  979.13  984.59  1779134671  9.307170e+12  4.101990e+14
# 1    985.50  986.00  977.74  981.10  1608837586  9.639650e+12  4.086270e+14
# 2    981.52  992.01  981.52  990.19  1704638309  8.903650e+12  4.126240e+14
# 3    990.16  990.16  983.02  987.58  2145264098  9.881300e+12  4.116270e+14
# 4    989.16  993.06  982.14  985.86  1954562972  9.593190e+12  4.109410e+14
# ..      ...     ...     ...     ...         ...           ...           ...
# 263  719.47  750.41  719.47  750.30   837119070  6.287370e+12  3.346940e+14
# 264  758.00  774.57  754.62  770.60   893324155  6.699470e+12  3.345460e+14
# 265  770.69  774.80  759.83  769.51   978286886  6.455440e+12  3.346840e+14
# 266  759.21  765.79  753.32  762.35   819568049  5.970950e+12  3.316670e+14
# 267  762.45  762.45  744.24  745.44   910028517  6.318520e+12  3.251640e+14
#
# ...

# %%
MERGE_DF.set_index('date', inplace = True)
MERGE_DF
# Out:
#             Open    High     Low   Close         거래량          거래대금  \
# date
# 20210601  982.25  984.61  979.13  984.59  1779134671  9.307170e+12
# 20210602  985.50  986.00  977.74  981.10  1608837586  9.639650e+12
# 20210603  981.52  992.01  981.52  990.19  1704638309  8.903650e+12
# 20210604  990.16  990.16  983.02  987.58  2145264098  9.881300e+12
# 20210607  989.16  993.06  982.14  985.86  1954562972  9.593190e+12
# ...          ...     ...     ...     ...         ...           ...
# 20220624  719.47  750.41  719.47  750.30   837119070  6.287370e+12
# 20220627  758.00  774.57  754.62  770.60   893324155  6.699470e+12
# 20220628  770.69  774.80  759.83  769.51   978286886  6.455440e+12
# 20220629  759.21  765.79  753.32  762.35   819568049  5.970950e+12
# 20220630  762.45  762.45  744.24  745.44   910028517  6.318520e+12
#
#                 상장시가총액    Change press_c  0_percent_c  ...  0_percent_f  \
# date                                                   ...
# ...

# %%
MERGE_DF.to_csv('data/final_train_KOSDAQ.csv',encoding='utf-8-sig')
