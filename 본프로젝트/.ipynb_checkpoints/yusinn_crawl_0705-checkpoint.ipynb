# %%
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm
import pandas as pd
import numpy as np

# %%
# 언론사 리스트
press_list = {'한국경제':'015', '매일경제':'009', '조선일보':'023', '동아일보':'020', '한겨례신문':'028', '경향신문':'032'}

# 크롤링 할 대상 입력
to_crawl_press_this_time = input("크롤링 할 언론사 : ")
presscode = press_list[to_crawl_press_this_time]


# 빈 DF 생성
df = pd.DataFrame(columns=["press","title","date"])

# 일년 반복문 
for month in range(1,13):
    print(f'{month}월 기사를 크롤링합니다.')
    print("**************************************")
    
    for day in tqdm(range(1,32)):   

        # URL에 접속 시도
        try:
            # 1 ~ 9일에 대한 URL 접근
            if i < 10:
                response = requests.get(f'https://media.naver.com/press/{presscode}/newspaper',
                             params = {'date':f'2022{month}0{day}'}
                            )
            # 10일부터에 대한 URL 접근
            else:
                response = requests.get(f'https://media.naver.com/press/{presscode}/newspaper',
                             params = {'date':f'2022{month}{day}'}
                            )

            # html 파싱 시작
            soup = BeautifulSoup(response.text)
            page = soup.select('div.newspaper_inner')

            # 혹시나 1면도 없으면 신문 없는 날
            if len(page) < 1:
                print(f'{day}일자는 기사가 없습니다 데헷')
                print('-' * 25)
                continue

            # 신문 지면 발견하면 크롤링
            else:
                print(f'{day}일자 기사를 크롤링합니다.')
                print('-' * 25)

                # 하루치 기사를 담을 리스트
                oneday_titles = []

                # 지면별 헤드라인 탐색
                for _ in range(len(page)):
                    page_titles = []
                    title = soup.select('div.newspaper_inner')[_]
                    titles = title.find_all('strong')

                    # 헤드라인들 page_title 리스트에 담음
                    for j in titles:
                        page_titles.append(j.text)

                # 하루치 기사 담아주기(1)
                    oneday_titles.append(page_titles)


                if i < 10:
                    page_dict = {'press':to_crawl_press_this_time,'title':oneday_titles, 'date':f'2022{month}0{day}'}
                    df.append(page_dict)
                else:
                    page_dict = {'press':to_crawl_press_this_time,'title':oneday_titles, 'date':f'2022{month}{day}'}
                    df.append(page_dict)



        # URL 접속 안되면 신문 없는 날    
        except:
            print(f'{i}일자는 기사가 없습니다 데헷')
            print('-' * 25)
            continue
# Out:
# 크롤링 할 언론사 : 조선일보
# 1월 기사를 크롤링합니다.
# **************************************
#   6%|████▊                                                                      | 2/31 [00:00<00:01, 19.83it/s]
# 1일자는 기사가 없습니다 데헷
# -------------------------
# 2일자는 기사가 없습니다 데헷
# -------------------------
# 3일자는 기사가 없습니다 데헷
# -------------------------
# 4일자는 기사가 없습니다 데헷
# -------------------------
#  16%|████████████                                                               | 5/31 [00:00<00:01, 21.20it/s]
# 5일자는 기사가 없습니다 데헷
# -------------------------
#  26%|███████████████████▎                                                       | 8/31 [00:00<00:01, 19.93it/s]
# 6일자는 기사가 없습니다 데헷
# -------------------------
# 7일자는 기사가 없습니다 데헷
# -------------------------
# 8일자는 기사가 없습니다 데헷
# -------------------------
# 9일자는 기사가 없습니다 데헷
#  42%|███████████████████████████████                                           | 13/31 [00:00<00:00, 18.21it/s]
# -------------------------
# 10일자는 기사가 없습니다 데헷
# -------------------------
# 11일자는 기사가 없습니다 데헷
# -------------------------
# 12일자는 기사가 없습니다 데헷
# -------------------------
# 13일자는 기사가 없습니다 데헷
# -------------------------
#  55%|████████████████████████████████████████▌                                 | 17/31 [00:00<00:00, 16.30it/s]
# 14일자는 기사가 없습니다 데헷
# -------------------------
# 15일자는 기사가 없습니다 데헷
# -------------------------
# 16일자는 기사가 없습니다 데헷
# -------------------------
# 17일자는 기사가 없습니다 데헷
# -------------------------
#  68%|██████████████████████████████████████████████████▏                       | 21/31 [00:01<00:00, 17.68it/s]
# 18일자는 기사가 없습니다 데헷
# -------------------------
# 19일자는 기사가 없습니다 데헷
# -------------------------
# 20일자는 기사가 없습니다 데헷
# -------------------------
# 21일자는 기사가 없습니다 데헷
# -------------------------
# 22일자는 기사가 없습니다 데헷
# -------------------------
#  81%|███████████████████████████████████████████████████████████▋              | 25/31 [00:01<00:00, 13.36it/s]
# 23일자는 기사가 없습니다 데헷
# -------------------------
# 24일자는 기사가 없습니다 데헷
# -------------------------
# 25일자는 기사가 없습니다 데헷
# -------------------------
#  97%|███████████████████████████████████████████████████████████████████████▌  | 30/31 [00:01<00:00, 16.62it/s]
# 26일자는 기사가 없습니다 데헷
# -------------------------
# 27일자는 기사가 없습니다 데헷
# -------------------------
# 28일자는 기사가 없습니다 데헷
# -------------------------
# 29일자는 기사가 없습니다 데헷
# -------------------------
# 30일자는 기사가 없습니다 데헷
# -------------------------
# 100%|██████████████████████████████████████████████████████████████████████████| 31/31 [00:01<00:00, 16.70it/s]
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 2월 기사를 크롤링합니다.
# **************************************
#  10%|███████▎                                                                   | 3/31 [00:00<00:01, 19.22it/s]
# 1일자는 기사가 없습니다 데헷
# -------------------------
# 2일자는 기사가 없습니다 데헷
# -------------------------
# 3일자는 기사가 없습니다 데헷
# -------------------------
# 4일자는 기사가 없습니다 데헷
# -------------------------
# 5일자는 기사가 없습니다 데헷
# -------------------------
#  29%|█████████████████████▊                                                     | 9/31 [00:00<00:01, 19.75it/s]
# 6일자는 기사가 없습니다 데헷
# -------------------------
# 7일자는 기사가 없습니다 데헷
# -------------------------
# 8일자는 기사가 없습니다 데헷
# -------------------------
# 9일자는 기사가 없습니다 데헷
# -------------------------
# 10일자는 기사가 없습니다 데헷
#  39%|████████████████████████████▋                                             | 12/31 [00:00<00:00, 20.10it/s]
# -------------------------
# 11일자는 기사가 없습니다 데헷
# -------------------------
# 12일자는 기사가 없습니다 데헷
# -------------------------
# 13일자는 기사가 없습니다 데헷
# -------------------------
# 14일자는 기사가 없습니다 데헷
# -------------------------
#  58%|██████████████████████████████████████████▉                               | 18/31 [00:00<00:00, 20.03it/s]
# 15일자는 기사가 없습니다 데헷
# -------------------------
# 16일자는 기사가 없습니다 데헷
# -------------------------
# 17일자는 기사가 없습니다 데헷
# -------------------------
# 18일자는 기사가 없습니다 데헷
# -------------------------
#  68%|██████████████████████████████████████████████████▏                       | 21/31 [00:01<00:00, 19.97it/s]
# 19일자는 기사가 없습니다 데헷
# -------------------------
# 20일자는 기사가 없습니다 데헷
# -------------------------
# 21일자는 기사가 없습니다 데헷
# -------------------------
# 22일자는 기사가 없습니다 데헷
# -------------------------
# 23일자는 기사가 없습니다 데헷
# -------------------------
#  87%|████████████████████████████████████████████████████████████████▍         | 27/31 [00:01<00:00, 19.93it/s]
# 24일자는 기사가 없습니다 데헷
# -------------------------
# 25일자는 기사가 없습니다 데헷
# -------------------------
# 26일자는 기사가 없습니다 데헷
# -------------------------
# 27일자는 기사가 없습니다 데헷
# -------------------------
# 28일자는 기사가 없습니다 데헷
# -------------------------
# 100%|██████████████████████████████████████████████████████████████████████████| 31/31 [00:01<00:00, 19.95it/s]
# 29일자는 기사가 없습니다 데헷
# -------------------------
# 30일자는 기사가 없습니다 데헷
# -------------------------
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 3월 기사를 크롤링합니다.
# **************************************
#   0%|                                                                                   | 0/31 [00:00<?, ?it/s]
# 1일자는 기사가 없습니다 데헷
# -------------------------
# 2일자는 기사가 없습니다 데헷
# -------------------------
#  10%|███████▎                                                                   | 3/31 [00:00<00:01, 20.65it/s]
# 3일자는 기사가 없습니다 데헷
# -------------------------
# 4일자는 기사가 없습니다 데헷
# -------------------------
# 5일자는 기사가 없습니다 데헷
# -------------------------
#  19%|██████████████▌                                                            | 6/31 [00:00<00:01, 20.33it/s]
# 6일자는 기사가 없습니다 데헷
# -------------------------
# 7일자는 기사가 없습니다 데헷
# -------------------------
#  29%|█████████████████████▊                                                     | 9/31 [00:00<00:01, 19.58it/s]
# 8일자는 기사가 없습니다 데헷
# -------------------------
# 9일자는 기사가 없습니다 데헷
# -------------------------
#  35%|██████████████████████████▎                                               | 11/31 [00:00<00:01, 19.71it/s]
# 10일자는 기사가 없습니다 데헷
# -------------------------
# 11일자는 기사가 없습니다 데헷
# -------------------------
#  45%|█████████████████████████████████▍                                        | 14/31 [00:00<00:00, 19.70it/s]
# 12일자는 기사가 없습니다 데헷
# -------------------------
# 13일자는 기사가 없습니다 데헷
# -------------------------
# 14일자는 기사가 없습니다 데헷
# -------------------------
#  52%|██████████████████████████████████████▏                                   | 16/31 [00:00<00:00, 19.49it/s]
# 15일자는 기사가 없습니다 데헷
# -------------------------
# 16일자는 기사가 없습니다 데헷
# -------------------------
#  61%|█████████████████████████████████████████████▎                            | 19/31 [00:00<00:00, 19.73it/s]
# 17일자는 기사가 없습니다 데헷
# -------------------------
# 18일자는 기사가 없습니다 데헷
# -------------------------
# 19일자는 기사가 없습니다 데헷
# -------------------------
# 20일자는 기사가 없습니다 데헷
# -------------------------
#  74%|██████████████████████████████████████████████████████▉                   | 23/31 [00:01<00:00, 19.31it/s]
# 21일자는 기사가 없습니다 데헷
# -------------------------
# 22일자는 기사가 없습니다 데헷
# -------------------------
# 23일자는 기사가 없습니다 데헷
# -------------------------
# 24일자는 기사가 없습니다 데헷
# -------------------------
# 25일자는 기사가 없습니다 데헷
#  84%|██████████████████████████████████████████████████████████████            | 26/31 [00:01<00:00, 19.79it/s]
# -------------------------
# 26일자는 기사가 없습니다 데헷
# -------------------------
# 27일자는 기사가 없습니다 데헷
# -------------------------
# 28일자는 기사가 없습니다 데헷
# -------------------------
# 100%|██████████████████████████████████████████████████████████████████████████| 31/31 [00:01<00:00, 19.67it/s]
# 29일자는 기사가 없습니다 데헷
# -------------------------
# 30일자는 기사가 없습니다 데헷
# -------------------------
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 4월 기사를 크롤링합니다.
# **************************************
#   0%|                                                                                   | 0/31 [00:00<?, ?it/s]
# 1일자는 기사가 없습니다 데헷
# -------------------------
#  13%|█████████▋                                                                 | 4/31 [00:00<00:01, 18.76it/s]
# 2일자는 기사가 없습니다 데헷
# -------------------------
# 3일자는 기사가 없습니다 데헷
# -------------------------
# 4일자는 기사가 없습니다 데헷
# -------------------------
# 5일자는 기사가 없습니다 데헷
# -------------------------
#  26%|███████████████████▎                                                       | 8/31 [00:00<00:01, 19.26it/s]
# 6일자는 기사가 없습니다 데헷
# -------------------------
# 7일자는 기사가 없습니다 데헷
# -------------------------
# 8일자는 기사가 없습니다 데헷
# -------------------------
# 9일자는 기사가 없습니다 데헷
# -------------------------
#  32%|███████████████████████▊                                                  | 10/31 [00:00<00:01, 19.30it/s]
# 10일자는 기사가 없습니다 데헷
# -------------------------
#  39%|████████████████████████████▋                                             | 12/31 [00:00<00:00, 19.42it/s]
# 11일자는 기사가 없습니다 데헷
# -------------------------
# 12일자는 기사가 없습니다 데헷
# -------------------------
# 13일자는 기사가 없습니다 데헷
# -------------------------
# 14일자는 기사가 없습니다 데헷
# -------------------------
#  48%|███████████████████████████████████▊                                      | 15/31 [00:00<00:00, 20.00it/s]
# 15일자는 기사가 없습니다 데헷
# -------------------------
#  55%|████████████████████████████████████████▌                                 | 17/31 [00:00<00:00, 19.64it/s]
# 16일자는 기사가 없습니다 데헷
# -------------------------
# 17일자는 기사가 없습니다 데헷
# -------------------------
# 18일자는 기사가 없습니다 데헷
# -------------------------
#  61%|█████████████████████████████████████████████▎                            | 19/31 [00:00<00:00, 19.69it/s]
# 19일자는 기사가 없습니다 데헷
# -------------------------
# 20일자는 기사가 없습니다 데헷
# -------------------------
#  71%|████████████████████████████████████████████████████▌                     | 22/31 [00:01<00:00, 19.94it/s]
# 21일자는 기사가 없습니다 데헷
# -------------------------
# 22일자는 기사가 없습니다 데헷
# -------------------------
# 23일자는 기사가 없습니다 데헷
# -------------------------
# 24일자는 기사가 없습니다 데헷
# -------------------------
#  81%|███████████████████████████████████████████████████████████▋              | 25/31 [00:01<00:00, 19.23it/s]
# 25일자는 기사가 없습니다 데헷
# -------------------------
# 26일자는 기사가 없습니다 데헷
# -------------------------
#  87%|████████████████████████████████████████████████████████████████▍         | 27/31 [00:01<00:00, 19.05it/s]
# 27일자는 기사가 없습니다 데헷
# -------------------------
# 28일자는 기사가 없습니다 데헷
# -------------------------
# 100%|██████████████████████████████████████████████████████████████████████████| 31/31 [00:01<00:00, 19.17it/s]
# 29일자는 기사가 없습니다 데헷
# -------------------------
# 30일자는 기사가 없습니다 데헷
# -------------------------
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 100%|██████████████████████████████████████████████████████████████████████████| 31/31 [00:01<00:00, 19.32it/s]
# 5월 기사를 크롤링합니다.
# **************************************
#   0%|                                                                                   | 0/31 [00:00<?, ?it/s]
# 1일자는 기사가 없습니다 데헷
# -------------------------
# 2일자는 기사가 없습니다 데헷
# -------------------------
#  10%|███████▎                                                                   | 3/31 [00:00<00:01, 21.02it/s]
# 3일자는 기사가 없습니다 데헷
# -------------------------
# 4일자는 기사가 없습니다 데헷
# -------------------------
# 5일자는 기사가 없습니다 데헷
# -------------------------
#  19%|██████████████▌                                                            | 6/31 [00:00<00:01, 20.19it/s]
# 6일자는 기사가 없습니다 데헷
# -------------------------
# 7일자는 기사가 없습니다 데헷
# -------------------------
#  29%|█████████████████████▊                                                     | 9/31 [00:00<00:01, 18.93it/s]
# 8일자는 기사가 없습니다 데헷
# -------------------------
# 9일자는 기사가 없습니다 데헷
# -------------------------
# 10일자는 기사가 없습니다 데헷
# -------------------------
#  39%|████████████████████████████▋                                             | 12/31 [00:00<00:00, 19.65it/s]
# 11일자는 기사가 없습니다 데헷
# -------------------------
# 12일자는 기사가 없습니다 데헷
# -------------------------
# 13일자는 기사가 없습니다 데헷
# -------------------------
# 14일자는 기사가 없습니다 데헷
#  45%|█████████████████████████████████▍                                        | 14/31 [00:00<00:00, 19.31it/s]
# -------------------------
# 15일자는 기사가 없습니다 데헷
# -------------------------
#  52%|██████████████████████████████████████▏                                   | 16/31 [00:00<00:00, 18.96it/s]
# 16일자는 기사가 없습니다 데헷
# -------------------------
# 17일자는 기사가 없습니다 데헷
# -------------------------
#  65%|███████████████████████████████████████████████▋                          | 20/31 [00:01<00:00, 19.30it/s]
# 18일자는 기사가 없습니다 데헷
# -------------------------
# 19일자는 기사가 없습니다 데헷
# -------------------------
# 20일자는 기사가 없습니다 데헷
# -------------------------
# 21일자는 기사가 없습니다 데헷
# -------------------------
#  71%|████████████████████████████████████████████████████▌                     | 22/31 [00:01<00:00, 19.39it/s]
# 22일자는 기사가 없습니다 데헷
# -------------------------
# 23일자는 기사가 없습니다 데헷
# -------------------------
# 24일자는 기사가 없습니다 데헷
# -------------------------
#  90%|██████████████████████████████████████████████████████████████████▊       | 28/31 [00:01<00:00, 17.53it/s]
# 25일자는 기사가 없습니다 데헷
# -------------------------
# 26일자는 기사가 없습니다 데헷
# -------------------------
# 27일자는 기사가 없습니다 데헷
# -------------------------
# 28일자는 기사가 없습니다 데헷
# -------------------------
# 29일자는 기사가 없습니다 데헷
# -------------------------
# 100%|██████████████████████████████████████████████████████████████████████████| 31/31 [00:01<00:00, 18.53it/s]
# 30일자는 기사가 없습니다 데헷
# -------------------------
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 6월 기사를 크롤링합니다.
# **************************************
#   6%|████▊                                                                      | 2/31 [00:00<00:01, 19.24it/s]
# 1일자는 기사가 없습니다 데헷
# -------------------------
# 2일자는 기사가 없습니다 데헷
# -------------------------
#  13%|█████████▋                                                                 | 4/31 [00:00<00:01, 17.62it/s]
# 3일자는 기사가 없습니다 데헷
# -------------------------
# 4일자는 기사가 없습니다 데헷
# -------------------------
#  19%|██████████████▌                                                            | 6/31 [00:00<00:01, 16.89it/s]
# 5일자는 기사가 없습니다 데헷
# -------------------------
# 6일자는 기사가 없습니다 데헷
# -------------------------
#  26%|███████████████████▎                                                       | 8/31 [00:00<00:01, 16.89it/s]
# 7일자는 기사가 없습니다 데헷
# -------------------------
# 8일자는 기사가 없습니다 데헷
# -------------------------
#  32%|███████████████████████▊                                                  | 10/31 [00:00<00:01, 17.19it/s]
# 9일자는 기사가 없습니다 데헷
# -------------------------
# 10일자는 기사가 없습니다 데헷
# -------------------------
#  39%|████████████████████████████▋                                             | 12/31 [00:00<00:01, 17.48it/s]
# 11일자는 기사가 없습니다 데헷
# -------------------------
# 12일자는 기사가 없습니다 데헷
# -------------------------
#  45%|█████████████████████████████████▍                                        | 14/31 [00:00<00:00, 17.44it/s]
# 13일자는 기사가 없습니다 데헷
# -------------------------
# 14일자는 기사가 없습니다 데헷
# -------------------------
#  52%|██████████████████████████████████████▏                                   | 16/31 [00:00<00:00, 17.77it/s]
# 15일자는 기사가 없습니다 데헷
# -------------------------
# 16일자는 기사가 없습니다 데헷
# -------------------------
#  58%|██████████████████████████████████████████▉                               | 18/31 [00:01<00:00, 17.85it/s]
# 17일자는 기사가 없습니다 데헷
# -------------------------
# 18일자는 기사가 없습니다 데헷
# -------------------------
#  65%|███████████████████████████████████████████████▋                          | 20/31 [00:01<00:00, 17.51it/s]
# 19일자는 기사가 없습니다 데헷
# -------------------------
# 20일자는 기사가 없습니다 데헷
# -------------------------
#  74%|██████████████████████████████████████████████████████▉                   | 23/31 [00:01<00:00, 18.67it/s]
# 21일자는 기사가 없습니다 데헷
# -------------------------
# 22일자는 기사가 없습니다 데헷
# -------------------------
# 23일자는 기사가 없습니다 데헷
# -------------------------
# 24일자는 기사가 없습니다 데헷
# -------------------------
# 25일자는 기사가 없습니다 데헷
# -------------------------
#  84%|██████████████████████████████████████████████████████████████            | 26/31 [00:01<00:00, 18.59it/s]
# 26일자는 기사가 없습니다 데헷
# -------------------------
# 27일자는 기사가 없습니다 데헷
# -------------------------
#  90%|██████████████████████████████████████████████████████████████████▊       | 28/31 [00:01<00:00, 18.47it/s]
# 28일자는 기사가 없습니다 데헷
# -------------------------
# 29일자는 기사가 없습니다 데헷
# -------------------------
# 100%|██████████████████████████████████████████████████████████████████████████| 31/31 [00:01<00:00, 17.97it/s]
# 30일자는 기사가 없습니다 데헷
# -------------------------
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 7월 기사를 크롤링합니다.
# **************************************
#   6%|████▊                                                                      | 2/31 [00:00<00:02, 13.95it/s]
# 1일자는 기사가 없습니다 데헷
# -------------------------
# 2일자는 기사가 없습니다 데헷
# -------------------------
#  13%|█████████▋                                                                 | 4/31 [00:00<00:01, 16.36it/s]
# 3일자는 기사가 없습니다 데헷
# -------------------------
# 4일자는 기사가 없습니다 데헷
# -------------------------
#  19%|██████████████▌                                                            | 6/31 [00:00<00:01, 17.14it/s]
# 5일자는 기사가 없습니다 데헷
# -------------------------
# 6일자는 기사가 없습니다 데헷
# -------------------------
#  26%|███████████████████▎                                                       | 8/31 [00:00<00:01, 18.00it/s]
# 7일자는 기사가 없습니다 데헷
# -------------------------
# 8일자는 기사가 없습니다 데헷
# -------------------------
# 9일자는 기사가 없습니다 데헷
# -------------------------
#  32%|███████████████████████▊                                                  | 10/31 [00:00<00:01, 18.65it/s]
# 10일자는 기사가 없습니다 데헷
# -------------------------
#  39%|████████████████████████████▋                                             | 12/31 [00:00<00:01, 18.66it/s]
# 11일자는 기사가 없습니다 데헷
# -------------------------
# 12일자는 기사가 없습니다 데헷
# -------------------------
# 13일자는 기사가 없습니다 데헷
# -------------------------
#  48%|███████████████████████████████████▊                                      | 15/31 [00:00<00:00, 19.52it/s]
# 14일자는 기사가 없습니다 데헷
# -------------------------
# 15일자는 기사가 없습니다 데헷
# -------------------------
#  55%|████████████████████████████████████████▌                                 | 17/31 [00:00<00:00, 19.18it/s]
# 16일자는 기사가 없습니다 데헷
# -------------------------
# 17일자는 기사가 없습니다 데헷
# -------------------------
#  61%|█████████████████████████████████████████████▎                            | 19/31 [00:01<00:00, 19.23it/s]
# 18일자는 기사가 없습니다 데헷
# -------------------------
# 19일자는 기사가 없습니다 데헷
# -------------------------
# 20일자는 기사가 없습니다 데헷
#  71%|████████████████████████████████████████████████████▌                     | 22/31 [00:01<00:00, 19.73it/s]
# -------------------------
# 21일자는 기사가 없습니다 데헷
# -------------------------
# 22일자는 기사가 없습니다 데헷
# -------------------------
# 23일자는 기사가 없습니다 데헷
# -------------------------
# 24일자는 기사가 없습니다 데헷
# -------------------------
#  81%|███████████████████████████████████████████████████████████▋              | 25/31 [00:01<00:00, 20.13it/s]
# 25일자는 기사가 없습니다 데헷
# -------------------------
# 26일자는 기사가 없습니다 데헷
# -------------------------
#  90%|██████████████████████████████████████████████████████████████████▊       | 28/31 [00:01<00:00, 18.26it/s]
# 27일자는 기사가 없습니다 데헷
# -------------------------
# 28일자는 기사가 없습니다 데헷
# -------------------------
#  97%|███████████████████████████████████████████████████████████████████████▌  | 30/31 [00:01<00:00, 18.51it/s]
# 29일자는 기사가 없습니다 데헷
# -------------------------
# 30일자는 기사가 없습니다 데헷
# -------------------------
# 100%|██████████████████████████████████████████████████████████████████████████| 31/31 [00:01<00:00, 18.60it/s]
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 8월 기사를 크롤링합니다.
# **************************************
#   0%|                                                                                   | 0/31 [00:00<?, ?it/s]
# 1일자는 기사가 없습니다 데헷
# -------------------------
#   6%|████▊                                                                      | 2/31 [00:00<00:01, 17.93it/s]
# 2일자는 기사가 없습니다 데헷
# -------------------------
# 3일자는 기사가 없습니다 데헷
# -------------------------
#  13%|█████████▋                                                                 | 4/31 [00:00<00:01, 17.85it/s]
# 4일자는 기사가 없습니다 데헷
# -------------------------
# 5일자는 기사가 없습니다 데헷
# -------------------------
#  26%|███████████████████▎                                                       | 8/31 [00:00<00:01, 18.48it/s]
# 6일자는 기사가 없습니다 데헷
# -------------------------
# 7일자는 기사가 없습니다 데헷
# -------------------------
# 8일자는 기사가 없습니다 데헷
# -------------------------
# 9일자는 기사가 없습니다 데헷
# -------------------------
#  32%|███████████████████████▊                                                  | 10/31 [00:00<00:01, 18.50it/s]
# 10일자는 기사가 없습니다 데헷
# -------------------------
# 11일자는 기사가 없습니다 데헷
# -------------------------
# 12일자는 기사가 없습니다 데헷
# -------------------------
#  42%|███████████████████████████████                                           | 13/31 [00:00<00:00, 19.08it/s]
# 13일자는 기사가 없습니다 데헷
# -------------------------
# 14일자는 기사가 없습니다 데헷
# -------------------------
#  55%|████████████████████████████████████████▌                                 | 17/31 [00:00<00:00, 19.07it/s]
# 15일자는 기사가 없습니다 데헷
# -------------------------
# 16일자는 기사가 없습니다 데헷
# -------------------------
# 17일자는 기사가 없습니다 데헷
# -------------------------
#  61%|█████████████████████████████████████████████▎                            | 19/31 [00:01<00:00, 19.17it/s]
# 18일자는 기사가 없습니다 데헷
# -------------------------
# 19일자는 기사가 없습니다 데헷
# -------------------------
#  68%|██████████████████████████████████████████████████▏                       | 21/31 [00:01<00:00, 18.52it/s]
# 20일자는 기사가 없습니다 데헷
# -------------------------
# 21일자는 기사가 없습니다 데헷
# -------------------------
#  74%|██████████████████████████████████████████████████████▉                   | 23/31 [00:01<00:00, 18.94it/s]
# 22일자는 기사가 없습니다 데헷
# -------------------------
# 23일자는 기사가 없습니다 데헷
# -------------------------
#  81%|███████████████████████████████████████████████████████████▋              | 25/31 [00:01<00:00, 18.71it/s]
# 24일자는 기사가 없습니다 데헷
# -------------------------
# 25일자는 기사가 없습니다 데헷
# -------------------------
# 26일자는 기사가 없습니다 데헷
# -------------------------
#  87%|████████████████████████████████████████████████████████████████▍         | 27/31 [00:01<00:00, 18.85it/s]
# 27일자는 기사가 없습니다 데헷
# -------------------------
# 28일자는 기사가 없습니다 데헷
#  94%|█████████████████████████████████████████████████████████████████████▏    | 29/31 [00:01<00:00, 18.99it/s]
# -------------------------
# 29일자는 기사가 없습니다 데헷
# -------------------------
# 30일자는 기사가 없습니다 데헷
# -------------------------
# 31일자는 기사가 없습니다 데헷
# 100%|██████████████████████████████████████████████████████████████████████████| 31/31 [00:01<00:00, 18.75it/s]
# -------------------------
# 9월 기사를 크롤링합니다.
# **************************************
#   6%|████▊                                                                      | 2/31 [00:00<00:01, 17.99it/s]
# 1일자는 기사가 없습니다 데헷
# -------------------------
# 2일자는 기사가 없습니다 데헷
# -------------------------
# 3일자는 기사가 없습니다 데헷
# -------------------------
# 4일자는 기사가 없습니다 데헷
# -------------------------
#  23%|████████████████▉                                                          | 7/31 [00:00<00:01, 18.93it/s]
# 5일자는 기사가 없습니다 데헷
# -------------------------
# 6일자는 기사가 없습니다 데헷
# -------------------------
# 7일자는 기사가 없습니다 데헷
# -------------------------
# 8일자는 기사가 없습니다 데헷
# -------------------------
#  35%|██████████████████████████▎                                               | 11/31 [00:00<00:01, 18.88it/s]
# 9일자는 기사가 없습니다 데헷
# -------------------------
# 10일자는 기사가 없습니다 데헷
# -------------------------
# 11일자는 기사가 없습니다 데헷
# -------------------------
# 12일자는 기사가 없습니다 데헷
# -------------------------
#  52%|██████████████████████████████████████▏                                   | 16/31 [00:00<00:00, 19.39it/s]
# 13일자는 기사가 없습니다 데헷
# -------------------------
# 14일자는 기사가 없습니다 데헷
# -------------------------
# 15일자는 기사가 없습니다 데헷
# -------------------------
# 16일자는 기사가 없습니다 데헷
# -------------------------
#  58%|██████████████████████████████████████████▉                               | 18/31 [00:00<00:00, 19.35it/s]
# 17일자는 기사가 없습니다 데헷
# -------------------------
# 18일자는 기사가 없습니다 데헷
# -------------------------
# 19일자는 기사가 없습니다 데헷
# -------------------------
# 20일자는 기사가 없습니다 데헷
# -------------------------
#  74%|██████████████████████████████████████████████████████▉                   | 23/31 [00:01<00:00, 19.56it/s]
# 21일자는 기사가 없습니다 데헷
# -------------------------
# 22일자는 기사가 없습니다 데헷
# -------------------------
# 23일자는 기사가 없습니다 데헷
# -------------------------
# 24일자는 기사가 없습니다 데헷
# -------------------------
#  87%|████████████████████████████████████████████████████████████████▍         | 27/31 [00:01<00:00, 19.67it/s]
# 25일자는 기사가 없습니다 데헷
# -------------------------
# 26일자는 기사가 없습니다 데헷
# -------------------------
# 27일자는 기사가 없습니다 데헷
# -------------------------
# 28일자는 기사가 없습니다 데헷
# -------------------------
# 29일자는 기사가 없습니다 데헷
# -------------------------
# 100%|██████████████████████████████████████████████████████████████████████████| 31/31 [00:01<00:00, 19.46it/s]
# 30일자는 기사가 없습니다 데헷
# -------------------------
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 10월 기사를 크롤링합니다.
# **************************************
#   6%|████▊                                                                      | 2/31 [00:00<00:01, 17.80it/s]
# 1일자는 기사가 없습니다 데헷
# -------------------------
# 2일자는 기사가 없습니다 데헷
# -------------------------
#  13%|█████████▋                                                                 | 4/31 [00:00<00:01, 19.00it/s]
# 3일자는 기사가 없습니다 데헷
# -------------------------
# 4일자는 기사가 없습니다 데헷
# -------------------------
#  19%|██████████████▌                                                            | 6/31 [00:00<00:01, 18.45it/s]
# 5일자는 기사가 없습니다 데헷
# -------------------------
# 6일자는 기사가 없습니다 데헷
# -------------------------
# 7일자는 기사가 없습니다 데헷
# -------------------------
#  26%|███████████████████▎                                                       | 8/31 [00:00<00:01, 15.03it/s]
# 8일자는 기사가 없습니다 데헷
# -------------------------
# 9일자는 기사가 없습니다 데헷
# -------------------------
# 10일자 기사를 크롤링합니다.
# -------------------------
#  32%|███████████████████████▊                                                  | 10/31 [00:00<00:01, 10.80it/s]
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 11일자 기사를 크롤링합니다.
# -------------------------
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 12일자 기사를 크롤링합니다.
# -------------------------
#  39%|████████████████████████████▋                                             | 12/31 [00:01<00:02,  7.43it/s]
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 13일자 기사를 크롤링합니다.
# -------------------------
#  42%|███████████████████████████████                                           | 13/31 [00:01<00:02,  6.46it/s]
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 14일자 기사를 크롤링합니다.
# -------------------------
#  45%|█████████████████████████████████▍                                        | 14/31 [00:01<00:02,  5.89it/s]
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 15일자 기사를 크롤링합니다.
# -------------------------
# 31일자는 기사가 없습니다 데헷
#  48%|███████████████████████████████████▊                                      | 15/31 [00:01<00:02,  5.69it/s]
# -------------------------
# 16일자 기사를 크롤링합니다.
# -------------------------
#  52%|██████████████████████████████████████▏                                   | 16/31 [00:02<00:02,  5.41it/s]
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 17일자 기사를 크롤링합니다.
# -------------------------
#  55%|████████████████████████████████████████▌                                 | 17/31 [00:02<00:02,  5.11it/s]
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 18일자 기사를 크롤링합니다.
# -------------------------
#  58%|██████████████████████████████████████████▉                               | 18/31 [00:02<00:02,  4.87it/s]
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 19일자 기사를 크롤링합니다.
# -------------------------
#  61%|█████████████████████████████████████████████▎                            | 19/31 [00:02<00:02,  4.76it/s]
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 20일자 기사를 크롤링합니다.
# -------------------------
#  65%|███████████████████████████████████████████████▋                          | 20/31 [00:02<00:02,  4.74it/s]
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 21일자 기사를 크롤링합니다.
# -------------------------
#  71%|████████████████████████████████████████████████████▌                     | 22/31 [00:03<00:01,  4.69it/s]
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 22일자 기사를 크롤링합니다.
# -------------------------
# 31일자는 기사가 없습니다 데헷
# -------------------------
#  74%|██████████████████████████████████████████████████████▉                   | 23/31 [00:03<00:01,  4.20it/s]
# 23일자 기사를 크롤링합니다.
# -------------------------
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 24일자 기사를 크롤링합니다.
# -------------------------
#  81%|███████████████████████████████████████████████████████████▋              | 25/31 [00:04<00:01,  4.43it/s]
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 25일자 기사를 크롤링합니다.
# -------------------------
# 31일자는 기사가 없습니다 데헷
# -------------------------
#  84%|██████████████████████████████████████████████████████████████            | 26/31 [00:04<00:01,  4.55it/s]
# 26일자 기사를 크롤링합니다.
# -------------------------
# 31일자는 기사가 없습니다 데헷
# -------------------------
#  87%|████████████████████████████████████████████████████████████████▍         | 27/31 [00:04<00:00,  4.59it/s]
# 27일자 기사를 크롤링합니다.
# -------------------------
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 28일자 기사를 크롤링합니다.
# -------------------------
#  94%|█████████████████████████████████████████████████████████████████████▏    | 29/31 [00:04<00:00,  5.50it/s]
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 30일자 기사를 크롤링합니다.
# -------------------------
#  97%|███████████████████████████████████████████████████████████████████████▌  | 30/31 [00:05<00:00,  5.44it/s]
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 31일자 기사를 크롤링합니다.
# -------------------------
# 100%|██████████████████████████████████████████████████████████████████████████| 31/31 [00:05<00:00,  5.91it/s]
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 11월 기사를 크롤링합니다.
# **************************************
#  10%|███████▎                                                                   | 3/31 [00:00<00:01, 20.87it/s]
# 1일자는 기사가 없습니다 데헷
# -------------------------
# 2일자는 기사가 없습니다 데헷
# -------------------------
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 4일자는 기사가 없습니다 데헷
# -------------------------
# 5일자는 기사가 없습니다 데헷
# -------------------------
#  19%|██████████████▌                                                            | 6/31 [00:00<00:01, 20.54it/s]
# 6일자는 기사가 없습니다 데헷
# -------------------------
# 7일자는 기사가 없습니다 데헷
# -------------------------
# 8일자는 기사가 없습니다 데헷
# -------------------------
#  29%|█████████████████████▊                                                     | 9/31 [00:00<00:01, 19.48it/s]
# 9일자는 기사가 없습니다 데헷
# -------------------------
# 10일자 기사를 크롤링합니다.
# -------------------------
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 11일자 기사를 크롤링합니다.
# -------------------------
# 31일자는 기사가 없습니다 데헷
#  35%|██████████████████████████▎                                               | 11/31 [00:00<00:01, 10.19it/s]
# -------------------------
# 12일자 기사를 크롤링합니다.
# -------------------------
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 13일자 기사를 크롤링합니다.
# -------------------------
#  42%|███████████████████████████████                                           | 13/31 [00:01<00:02,  7.51it/s]
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 14일자 기사를 크롤링합니다.
# -------------------------
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 15일자 기사를 크롤링합니다.
# -------------------------
#  48%|███████████████████████████████████▊                                      | 15/31 [00:01<00:02,  5.64it/s]
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 16일자 기사를 크롤링합니다.
# -------------------------
#  52%|██████████████████████████████████████▏                                   | 16/31 [00:02<00:02,  5.37it/s]
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 17일자 기사를 크롤링합니다.
# -------------------------
#  55%|████████████████████████████████████████▌                                 | 17/31 [00:02<00:02,  5.15it/s]
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 18일자 기사를 크롤링합니다.
# -------------------------
#  61%|█████████████████████████████████████████████▎                            | 19/31 [00:02<00:02,  4.94it/s]
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 19일자 기사를 크롤링합니다.
# -------------------------
# 31일자는 기사가 없습니다 데헷
# -------------------------
#  65%|███████████████████████████████████████████████▋                          | 20/31 [00:02<00:02,  4.92it/s]
# 20일자 기사를 크롤링합니다.
# -------------------------
# 31일자는 기사가 없습니다 데헷
# -------------------------
#  68%|██████████████████████████████████████████████████▏                       | 21/31 [00:03<00:02,  4.83it/s]
# 21일자 기사를 크롤링합니다.
# -------------------------
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 22일자 기사를 크롤링합니다.
# -------------------------
#  71%|████████████████████████████████████████████████████▌                     | 22/31 [00:03<00:01,  4.84it/s]
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 23일자 기사를 크롤링합니다.
# -------------------------
#  74%|██████████████████████████████████████████████████████▉                   | 23/31 [00:03<00:01,  4.82it/s]
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 24일자 기사를 크롤링합니다.
# -------------------------
#  81%|███████████████████████████████████████████████████████████▋              | 25/31 [00:03<00:01,  4.91it/s]
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 25일자 기사를 크롤링합니다.
# -------------------------
# 31일자는 기사가 없습니다 데헷
# -------------------------
#  84%|██████████████████████████████████████████████████████████████            | 26/31 [00:04<00:01,  4.99it/s]
# 26일자 기사를 크롤링합니다.
# -------------------------
# 31일자는 기사가 없습니다 데헷
# -------------------------
#  87%|████████████████████████████████████████████████████████████████▍         | 27/31 [00:04<00:00,  4.44it/s]
# 27일자 기사를 크롤링합니다.
# -------------------------
# 31일자는 기사가 없습니다 데헷
# -------------------------
#  90%|██████████████████████████████████████████████████████████████████▊       | 28/31 [00:04<00:00,  4.32it/s]
# 28일자 기사를 크롤링합니다.
# -------------------------
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 29일자 기사를 크롤링합니다.
# -------------------------
#  97%|███████████████████████████████████████████████████████████████████████▌  | 30/31 [00:05<00:00,  4.72it/s]
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 30일자 기사를 크롤링합니다.
# -------------------------
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 100%|██████████████████████████████████████████████████████████████████████████| 31/31 [00:05<00:00,  6.02it/s]
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 12월 기사를 크롤링합니다.
# **************************************
#  10%|███████▎                                                                   | 3/31 [00:00<00:01, 21.12it/s]
# 1일자는 기사가 없습니다 데헷
# -------------------------
# 2일자는 기사가 없습니다 데헷
# -------------------------
# 3일자는 기사가 없습니다 데헷
# -------------------------
# 4일자는 기사가 없습니다 데헷
# -------------------------
# 5일자는 기사가 없습니다 데헷
# -------------------------
#  29%|█████████████████████▊                                                     | 9/31 [00:00<00:01, 20.14it/s]
# 6일자는 기사가 없습니다 데헷
# -------------------------
# 7일자는 기사가 없습니다 데헷
# -------------------------
# 8일자는 기사가 없습니다 데헷
# -------------------------
# 9일자는 기사가 없습니다 데헷
# -------------------------
# 10일자 기사를 크롤링합니다.
# -------------------------
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 11일자 기사를 크롤링합니다.
# -------------------------
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 12일자 기사를 크롤링합니다.
# -------------------------
#  39%|████████████████████████████▋                                             | 12/31 [00:01<00:02,  8.90it/s]
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 13일자 기사를 크롤링합니다.
# -------------------------
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 14일자 기사를 크롤링합니다.
# -------------------------
# 31일자는 기사가 없습니다 데헷
#  45%|█████████████████████████████████▍                                        | 14/31 [00:01<00:02,  7.30it/s]
# -------------------------
# 15일자 기사를 크롤링합니다.
# -------------------------
#  52%|██████████████████████████████████████▏                                   | 16/31 [00:01<00:02,  6.43it/s]
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 16일자 기사를 크롤링합니다.
# -------------------------
# 31일자는 기사가 없습니다 데헷
# -------------------------
#  55%|████████████████████████████████████████▌                                 | 17/31 [00:02<00:02,  6.09it/s]
# 17일자 기사를 크롤링합니다.
# -------------------------
# 31일자는 기사가 없습니다 데헷
# -------------------------
#  61%|█████████████████████████████████████████████▎                            | 19/31 [00:02<00:01,  6.39it/s]
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 19일자 기사를 크롤링합니다.
# -------------------------
# 31일자는 기사가 없습니다 데헷
# -------------------------
#  65%|███████████████████████████████████████████████▋                          | 20/31 [00:02<00:01,  6.41it/s]
# 20일자 기사를 크롤링합니다.
# -------------------------
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 21일자 기사를 크롤링합니다.
# -------------------------
#  71%|████████████████████████████████████████████████████▌                     | 22/31 [00:02<00:01,  6.11it/s]
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 22일자 기사를 크롤링합니다.
# -------------------------
# 31일자는 기사가 없습니다 데헷
# -------------------------
#  74%|██████████████████████████████████████████████████████▉                   | 23/31 [00:03<00:01,  6.19it/s]
# 23일자 기사를 크롤링합니다.
# -------------------------
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 24일자 기사를 크롤링합니다.
# -------------------------
#  81%|███████████████████████████████████████████████████████████▋              | 25/31 [00:03<00:00,  6.20it/s]
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 25일자 기사를 크롤링합니다.
# -------------------------
# 31일자는 기사가 없습니다 데헷
# -------------------------
#  84%|██████████████████████████████████████████████████████████████            | 26/31 [00:03<00:00,  6.06it/s]
# 26일자 기사를 크롤링합니다.
# -------------------------
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 27일자 기사를 크롤링합니다.
# -------------------------
#  90%|██████████████████████████████████████████████████████████████████▊       | 28/31 [00:03<00:00,  5.69it/s]
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 28일자 기사를 크롤링합니다.
# -------------------------
# 31일자는 기사가 없습니다 데헷
# -------------------------
#  94%|█████████████████████████████████████████████████████████████████████▏    | 29/31 [00:04<00:00,  5.76it/s]
# 29일자 기사를 크롤링합니다.
# -------------------------
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 30일자 기사를 크롤링합니다.
# -------------------------
# 100%|██████████████████████████████████████████████████████████████████████████| 31/31 [00:04<00:00,  6.98it/s]
# 31일자는 기사가 없습니다 데헷
# -------------------------
# 31일자 기사를 크롤링합니다.
# -------------------------
# 31일자는 기사가 없습니다 데헷
# -------------------------

# %%
df
# Out:
# Empty DataFrame
# Columns: [press, title, date]
# Index: []

# %%
df.to_csv(f'{to_crawl_press_this_time}_22{to_crawl_month}.csv',encoding="cp949")
