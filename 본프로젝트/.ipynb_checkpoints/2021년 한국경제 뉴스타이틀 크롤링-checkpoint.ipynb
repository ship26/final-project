# %%
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm
import pandas as pd
import numpy as np
import time

# %% [markdown]
# https://news.naver.com/newspaper/home?viewType=pc
#
# URL 양식
# https://media.naver.com/press/
# {언론사고유번호}/newspaper?date={날짜}
#
# 한경 015
# 매경 009
# 조선 023
# 동아 020
# 한겨례 028
# 경향 032

# %% [markdown]
# ## 2021년  한국경제 타이틀크롤링 1월~12월 자동화 해보자! ㅍㅇㅌ

# %%
for k in range(1,13):
    globals()['df{}'.format(k)] = pd.DataFrame(columns=['press','title','date'])  #동적 변수 할당.
columns=['press','title','date']

for i in tqdm(range(1,13)):
    time.sleep(2)
    if i==1:
        for 월_1 in range(1,31):
            하루타이틀=[]
            if 월_1 <10:
                date='2021010{}'.format(월_1)
                response=requests.get('https://media.naver.com/press/015/newspaper',
                params={'date':date}
                )
            else:
                date='202101{}'.format(월_1)
                response=requests.get('https://media.naver.com/press/015/newspaper',
                params={'date':date}
                )
            
            soup=BeautifulSoup(response.text)
            면=soup.select('div.newspaper_inner')
    
            if len(면)<1:
                print(f'{월_1}일자는 기사가 없습니다 데헷')
                print('-'*25)
                continue
            else:
                print(f'{월_1}일자 기사 크롤링합니다.')
                print('-'*25)
                for 월1 in range(len(면)):
                    i면타이틀=[]
                    타이틀제목=soup.select('div.newspaper_inner')[월1]
                    타이틀제목s=타이틀제목.find_all('strong')
                    for x1 in 타이틀제목s:
                        i면타이틀.append(x1.text)
                    하루타이틀.append(i면타이틀)

                df1.loc[len(df1)]=['한국경제',하루타이틀,date]
        
        df1.to_csv('hankyong_202101.csv',encoding='cp949')
    
    elif i==2:
        for 월_2 in range(1,29):
            하루타이틀=[]
            if 월_2 <10:
                date='2021020{}'.format(월_2)
                response=requests.get('https://media.naver.com/press/015/newspaper',
                params={'date':date}
                )
            else:
                date='202102{}'.format(월_2)
                response=requests.get('https://media.naver.com/press/015/newspaper',
                params={'date':date}
                )
            
            soup=BeautifulSoup(response.text)
            면=soup.select('div.newspaper_inner')
    
            if len(면)<1:
                print(f'{월_2}일자는 기사가 없습니다 데헷')
                print('-'*25)
                continue
            else:
                print(f'{월_2}일자 기사 크롤링합니다.')
                print('-'*25)
                for 월2 in range(len(면)):
                    i면타이틀=[]
                    타이틀제목=soup.select('div.newspaper_inner')[월2]
                    타이틀제목s=타이틀제목.find_all('strong')
                    for x2 in 타이틀제목s:
                        i면타이틀.append(x2.text)
                    하루타이틀.append(i면타이틀)

                df2.loc[len(df2)]=['한국경제',하루타이틀,date]

        df2.to_csv('hankyong_202102.csv',encoding='cp949')
               
    elif i==3:
        for 월_3 in range(1,32):
            하루타이틀=[]
            if 월_3 <10:
                date='2021030{}'.format(월_3)
                response=requests.get('https://media.naver.com/press/015/newspaper',
                params={'date':date}
                )
            else:
                date='202103{}'.format(월_3)
                response=requests.get('https://media.naver.com/press/015/newspaper',
                params={'date':date}
                )
            
            soup=BeautifulSoup(response.text)
            면=soup.select('div.newspaper_inner')
    
            if len(면)<1:
                print(f'{월_3}일자는 기사가 없습니다 데헷')
                print('-'*25)
                continue
            else:
                print(f'{월_3}일자 기사 크롤링합니다.')
                print('-'*25)
                for 월3 in range(len(면)):
                    i면타이틀=[]
                    타이틀제목=soup.select('div.newspaper_inner')[월3]
                    타이틀제목s=타이틀제목.find_all('strong')
                    for x3 in 타이틀제목s:
                        i면타이틀.append(x3.text)
                    하루타이틀.append(i면타이틀)

                df3.loc[len(df3)]=['한국경제',하루타이틀,date]

        df3.to_csv('hankyong_202103.csv',encoding='cp949')
    elif i==4:
        for 월_4 in range(1,31):
            하루타이틀=[]
            if 월_4 <10:
                date='2021040{}'.format(월_4)
                response=requests.get('https://media.naver.com/press/015/newspaper',
                params={'date':date}
                )
            else:
                date='202104{}'.format(월_4)
                response=requests.get('https://media.naver.com/press/015/newspaper',
                params={'date':date}
                )
            
            soup=BeautifulSoup(response.text)
            면=soup.select('div.newspaper_inner')
    
            if len(면)<1:
                print(f'{월_4}일자는 기사가 없습니다 데헷')
                print('-'*25)
                continue
            else:
                print(f'{월_4}일자 기사 크롤링합니다.')
                print('-'*25)
                for 월4 in range(len(면)):
                    i면타이틀=[]
                    타이틀제목=soup.select('div.newspaper_inner')[월4]
                    타이틀제목s=타이틀제목.find_all('strong')
                    for x2 in 타이틀제목s:
                        i면타이틀.append(x2.text)
                    하루타이틀.append(i면타이틀)

                df4.loc[len(df4)]=['한국경제',하루타이틀,date]

        df4.to_csv('hankyong_202104.csv',encoding='cp949')
                
    elif i==5:
        for 월_5 in range(1,32):
            하루타이틀=[]
            if 월_5 <10:
                date='2021050{}'.format(월_5)
                response=requests.get('https://media.naver.com/press/015/newspaper',
                params={'date':date}
                )
            else:
                date='202105{}'.format(월_5)
                response=requests.get('https://media.naver.com/press/015/newspaper',
                params={'date':date}
                )
            
            soup=BeautifulSoup(response.text)
            면=soup.select('div.newspaper_inner')
    
            if len(면)<1:
                print(f'{월_5}일자는 기사가 없습니다 데헷')
                print('-'*25)
                continue
            else:
                print(f'{월_5}일자 기사 크롤링합니다.')
                print('-'*25)
                for 월5 in range(len(면)):
                    i면타이틀=[]
                    타이틀제목=soup.select('div.newspaper_inner')[월5]
                    타이틀제목s=타이틀제목.find_all('strong')
                    for x5 in 타이틀제목s:
                        i면타이틀.append(x5.text)
                    하루타이틀.append(i면타이틀)

                df5.loc[len(df5)]=['한국경제',하루타이틀,date]

        df5.to_csv('hankyong_202105.csv',encoding='cp949')
    elif i==6:
        for 월_6 in range(1,31):
            하루타이틀=[]
            if 월_6 <10:
                date='2021060{}'.format(월_6)
                response=requests.get('https://media.naver.com/press/015/newspaper',
                params={'date':date}
                )
            else:
                date='202106{}'.format(월_6)
                response=requests.get('https://media.naver.com/press/015/newspaper',
                params={'date':date}
                )
            
            soup=BeautifulSoup(response.text)
            면=soup.select('div.newspaper_inner')
    
            if len(면)<1:
                print(f'{월_6}일자는 기사가 없습니다 데헷')
                print('-'*25)
                continue
            else:
                print(f'{월_6}일자 기사 크롤링합니다.')
                print('-'*25)
                for 월6 in range(len(면)):
                    i면타이틀=[]
                    타이틀제목=soup.select('div.newspaper_inner')[월6]
                    타이틀제목s=타이틀제목.find_all('strong')
                    for x6 in 타이틀제목s:
                        i면타이틀.append(x6.text)
                    하루타이틀.append(i면타이틀)

                df6.loc[len(df6)]=['한국경제',하루타이틀,date]

        df6.to_csv('hankyong_202106.csv',encoding='cp949')
        
    elif i==7:
        for 월_7 in range(1,32):
            하루타이틀=[]
            if 월_7 <10:
                date='2021070{}'.format(월_7)
                response=requests.get('https://media.naver.com/press/015/newspaper',
                params={'date':date}
                )
            else:
                date='202107{}'.format(월_7)
                response=requests.get('https://media.naver.com/press/015/newspaper',
                params={'date':date}
                )
            
            soup=BeautifulSoup(response.text)
            면=soup.select('div.newspaper_inner')
    
            if len(면)<1:
                print(f'{월_7}일자는 기사가 없습니다 데헷')
                print('-'*25)
                continue
            else:
                print(f'{월_7}일자 기사 크롤링합니다.')
                print('-'*25)
                for 월7 in range(len(면)):
                    i면타이틀=[]
                    타이틀제목=soup.select('div.newspaper_inner')[월7]
                    타이틀제목s=타이틀제목.find_all('strong')
                    for x7 in 타이틀제목s:
                        i면타이틀.append(x7.text)
                    하루타이틀.append(i면타이틀)

                df7.loc[len(df7)]=['한국경제',하루타이틀,date]

        df7.to_csv('hankyong_202107.csv',encoding='cp949')
        
    elif i==8:
        for 월_8 in range(1,32):
            하루타이틀=[]
            if 월_8 <10:
                date='2021080{}'.format(월_8)
                response=requests.get('https://media.naver.com/press/015/newspaper',
                params={'date':date}
                )
            else:
                date='202108{}'.format(월_8)
                response=requests.get('https://media.naver.com/press/015/newspaper',
                params={'date':date}
                )
            
            soup=BeautifulSoup(response.text)
            면=soup.select('div.newspaper_inner')
    
            if len(면)<1:
                print(f'{월_8}일자는 기사가 없습니다 데헷')
                print('-'*25)
                continue
            else:
                print(f'{월_8}일자 기사 크롤링합니다.')
                print('-'*25)
                for 월8 in range(len(면)):
                    i면타이틀=[]
                    타이틀제목=soup.select('div.newspaper_inner')[월8]
                    타이틀제목s=타이틀제목.find_all('strong')
                    for x8 in 타이틀제목s:
                        i면타이틀.append(x8.text)
                    하루타이틀.append(i면타이틀)

                df8.loc[len(df8)]=['한국경제',하루타이틀,date]

        df8.to_csv('hankyong_202108.csv',encoding='cp949')
        
    elif i==9:
        for 월_9 in range(1,31):
            하루타이틀=[]
            if 월_9 <10:
                date='2021090{}'.format(월_9)
                response=requests.get('https://media.naver.com/press/015/newspaper',
                params={'date':date}
                )
            else:
                date='202109{}'.format(월_9)
                response=requests.get('https://media.naver.com/press/015/newspaper',
                params={'date':date}
                )
            
            soup=BeautifulSoup(response.text)
            면=soup.select('div.newspaper_inner')
    
            if len(면)<1:
                print(f'{월_9}일자는 기사가 없습니다 데헷')
                print('-'*25)
                continue
            else:
                print(f'{월_9}일자 기사 크롤링합니다.')
                print('-'*25)
                for 월9 in range(len(면)):
                    i면타이틀=[]
                    타이틀제목=soup.select('div.newspaper_inner')[월9]
                    타이틀제목s=타이틀제목.find_all('strong')
                    for x9 in 타이틀제목s:
                        i면타이틀.append(x9.text)
                    하루타이틀.append(i면타이틀)

                df9.loc[len(df9)]=['한국경제',하루타이틀,date]

        df9.to_csv('hankyong_202109.csv',encoding='cp949')
        
    elif i==10:
        for 월_10 in range(1,32):
            하루타이틀=[]
            if 월_10 <10:
                date='2021100{}'.format(월_10)
                response=requests.get('https://media.naver.com/press/015/newspaper',
                params={'date':date}
                )
            else:
                date='202110{}'.format(월_10)
                response=requests.get('https://media.naver.com/press/015/newspaper',
                params={'date':date}
                )
            
            soup=BeautifulSoup(response.text)
            면=soup.select('div.newspaper_inner')
    
            if len(면)<1:
                print(f'{월_10}일자는 기사가 없습니다 데헷')
                print('-'*25)
                continue
            else:
                print(f'{월_10}일자 기사 크롤링합니다.')
                print('-'*25)
                for 월10 in range(len(면)):
                    i면타이틀=[]
                    타이틀제목=soup.select('div.newspaper_inner')[월10]
                    타이틀제목s=타이틀제목.find_all('strong')
                    for x10 in 타이틀제목s:
                        i면타이틀.append(x10.text)
                    하루타이틀.append(i면타이틀)

                df10.loc[len(df10)]=['한국경제',하루타이틀,date]

        df10.to_csv('hankyong_202110.csv',encoding='cp949')
        
    elif i==11:
        for 월_11 in range(1,31):
            하루타이틀=[]
            if 월_11 <10:
                date='2021110{}'.format(월_11)
                response=requests.get('https://media.naver.com/press/015/newspaper',
                params={'date':date}
                )
            else:
                date='202111{}'.format(월_11)
                response=requests.get('https://media.naver.com/press/015/newspaper',
                params={'date':date}
                )
            
            soup=BeautifulSoup(response.text)
            면=soup.select('div.newspaper_inner')
    
            if len(면)<1:
                print(f'{월_11}일자는 기사가 없습니다 데헷')
                print('-'*25)
                continue
            else:
                print(f'{월_11}일자 기사 크롤링합니다.')
                print('-'*25)
                for 월11 in range(len(면)):
                    i면타이틀=[]
                    타이틀제목=soup.select('div.newspaper_inner')[월11]
                    타이틀제목s=타이틀제목.find_all('strong')
                    for x11 in 타이틀제목s:
                        i면타이틀.append(x11.text)
                    하루타이틀.append(i면타이틀)

                df11.loc[len(df11)]=['한국경제',하루타이틀,date]

        df11.to_csv('hankyong_202111.csv',encoding='cp949')
        
    elif i==12:
        for 월_12 in range(1,29):
            하루타이틀=[]
            if 월_12 <10:
                date='2021120{}'.format(월_12)
                response=requests.get('https://media.naver.com/press/015/newspaper',
                params={'date':date}
                )
            else:
                date='202112{}'.format(월_12)
                response=requests.get('https://media.naver.com/press/015/newspaper',
                params={'date':date}
                )
            
            soup=BeautifulSoup(response.text)
            면=soup.select('div.newspaper_inner')
    
            if len(면)<1:
                print(f'{월_12}일자는 기사가 없습니다 데헷')
                print('-'*25)
                continue
            else:
                print(f'{월_12}일자 기사 크롤링합니다.')
                print('-'*25)
                for 월12 in range(len(면)):
                    i면타이틀=[]
                    타이틀제목=soup.select('div.newspaper_inner')[월12]
                    타이틀제목s=타이틀제목.find_all('strong')
                    for x12 in 타이틀제목s:
                        i면타이틀.append(x12.text)
                    하루타이틀.append(i면타이틀)

                df12.loc[len(df12)]=['한국경제',하루타이틀,date]

        df12.to_csv('hankyong_202112.csv',encoding='cp949')
# Out:
#   0%|                                                                                           | 0/12 [00:02<?, ?it/s]
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1370             try:
# -> 1371                 response.begin()
#    1372             except ConnectionError:
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#
# ~\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#
# ConnectionResetError: [WinError 10054] 현재 연결은 원격 호스트에 의해 강제로 끊겼습니다
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~\anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     531             if read is False or not self._is_method_retryable(method):
# --> 532                 raise six.reraise(type(error), error, _stacktrace)
#     533             elif read is not None:
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     768             if value.__traceback__ is not tb:
# --> 769                 raise value.with_traceback(tb)
#     770             raise value
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1370             try:
# -> 1371                 response.begin()
#    1372             except ConnectionError:
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#
# ~\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12836/1447067370.py in <module>
#      12             if 월_1 <10:
#      13                 date='2021010{}'.format(월_1)
# ---> 14                 response=requests.get('https://media.naver.com/press/015/newspaper',headers=request_headers,
#      15                 params={'date':date}
#      16                 )
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))

# %%
df12
# Out:
#    press                                              title      date
# 0   한국경제  [[한경 중고생 경제·논술신문 생글생글 확 달라졌습니다, 또 덮친 'O의 공포'…코...  20211201
# 1   한국경제  [[100조 땅값, 34조로 공시…'회계 사각지대' 교육청, 한국도 뚫렸다…오미크론...  20211202
# 2   한국경제  [[포스코케미칼, GM과 손잡는다, 608조 초슈퍼 예산…대선 돈풀기, SK 인사 ...  20211203
# 3   한국경제  [['백신패스' 전면 도입…사실상 접종 의무화, 607조7000억…슈퍼예산 국회 통...  20211204
# 4   한국경제  [[대출 규제서 한발 물러선 금융위…"중·저신용자는 총량 관리서 제외", 3만500...  20211206
# 5   한국경제  [[“건강검진 재검만 나와도 채용 안한다”, 미래에셋증권 회장에 최현만, 이재명 "...  20211207
# 6   한국경제  [[줄어드는 서민주택 알고보니 종부세 탓, '갤럭시Z플립3' 올해 최고 모바일기술,...  20211208
# 7   한국경제  [[25兆 50兆 100兆 포커판 닮아가는 돈풀기, 사양기업은 있어도 사양산업은 없...  20211209
# 8   한국경제  [[美 정부 차량, 2035년까지 전기차로 교체, 사망자 30% '위드코로나 40일...  20211210
# 9   한국경제  [['철강 꼬리표' 떼는 포스코…21년 만에 지주사 전환, 2023년 '대기업 新재...  20211211
# 10  한국경제  [[애플·퀄컴·아마존···미국주식 더 달린다, 현대차도 쇄신 인사···R&D·디자인...  20211213
# 11  한국경제  [[전세 쌓이는 서울…16개월 만에 '최다', '세계 무역 15%' 차지하는 CPT...  20211214
# 12  한국경제  [[알파고 능력의 300배…LG '초거대 AI' 개발, "내년 가계 살림 쥐어짜는 ...  20211215
# 13  한국경제  [[삼성 파운드리, ST마이크로·IBM 잡았다, 좌초된 위드 코로나…4단계로 돌아가...  20211216
# 14  한국경제  [[7622명 vs 159명…韓·日 방역 '4가지'가 갈랐다, 삼성전자 차량용 반도...  20211217
# 15  한국경제  [[매출 줄어든 소상공인에 방역지원금 100만원씩, 승객 50% 급감…지역 버스터미...  20211218
# 16  한국경제  [[이재명도 윤석열도 250만가구 공급…"숫자만 채웠다", 부스터샷도 뚫은 오미크론...  20211220
# 17  한국경제  [[당정 "내년 보유세 동결"…희한한 '1년짜리 세금 공약', "인플레 강타…내년 ...  20211221
# 18  한국경제  [[양도세 중과 유예 놓고 문재인 정부 신구 권력 '충돌', 네이버, 가상인간 '로...  20211222
# 19  한국경제  [[SK하이닉스 '인텔 낸드 인수' 中 승인 받았다, 내년에도 공시가 폭탄…땅값 1...  20211223
# 20  한국경제  [[코로나 '먹는 치료제' 확보…日 200만명 vs 韓 16만명분, [단독] 현대차...  20211224
# 21  한국경제  [[외국인 역대급 '셀코리아'…韓 증시만 맥 못췄다, 664만명 '나혼자 산다'…5...  20211225
# 22  한국경제  [['요소수 허점' 본 中…배터리 원료값 줄인상, 이재명 37.8% vs 윤석열 3...  20211227
# 23  한국경제  [[전기료·가스요금…대선 끝나고 다 올린다, 회계법인 긴급 지침…"가상자산 감사 피...  20211228
