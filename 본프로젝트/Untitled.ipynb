# %%
import pandas as pd
import numpy as np
import time

# %%
df=pd.read_csv('preprocessed_data.csv',index_col = 0)
df2.to_csv('Dataa.csv',encoding='utf-8-sig')

# %%
df2=df.sample(frac=1).reset_index(drop=True)
df2
# Out:
#       press                                              title      date  \
# 0      동아일보                     지난달 수출 512억달러… 10년만에 최대 41% 증가  20210503
# 1      경향신문                                 HDC현산, 영업정지 8개월 추가  20220414
# 2      한국경제                 "하반기 서울 아파트값, 신축·구축 할 것 없이 더 오를 것"  20200716
# 3      매일경제                         알뜰폰협회장 "통신3사, 알뜰폰 사업 철수해야"  20201028
# 4      경향신문                   17개월 만에 만난 미·중 국방, 대만·우크라 놓고 공방전  20220611
# ...     ...                                                ...       ...
# 10241  동아일보                            현대차, 中 광저우에 수소연료전지 생산기지  20210303
# 10242  동아일보                          은행권, 최고 금리 1%P 내려 소상공인 지원  20201230
# 10243  동아일보                    “신도들과 면마스크 제작하며 나눔과 섬김 몸소 체험했죠”  20210402
# 10244  동아일보                          與 “정세균 임명동의안 예정대로 13일 표결”  20200109
# 10245  매일경제  美대선 2차 TV토론 `갑론을박`…트럼프 `대면 방식` 고집하자 바이든 "날짜연기 ...  20201010
#
#        emotion
# 0          1.0
# 1          0.0
# 2          2.0
# 3          2.0
# ...

# %%
df2.

# %%
뉴스리스트1=[]
뉴스리스트2=[]
뉴스리스트3=[]

# %%
for i in range(1,10):
    df=pd.read_csv(f'title/동아일보/동아일보_2021_0{i}.csv',index_col = 0)
    df.dropna(inplace=True)
    df.reset_index(inplace=True)
    df.drop(['index'],axis=1,inplace=True)
    뉴스리스트1.append(df)
df1=pd.concat([i for i in  뉴스리스트1])
df1
# Out:
#     press                                        title      date  emotion
# 0    동아일보   서울시장 선거 지지율… 안철수 24.2% 박영선 17.5% 나경원 14.5%  20210101      2.0
# 1    동아일보                       확진 900명 넘어서야… ‘뒷북 법무부’  20210101      2.0
# 2    동아일보                     文, 靑비서실장 유영민-민정수석 신현수 임명  20210101      2.0
# 3    동아일보  ‘피겨 여왕’ 김연아 “어려울수록 강해지는 대한민국…이번에도 딛고 일어서야죠”  20210101      2.0
# 4    동아일보       “文정부 부동산정책 잘못” 70%육박… “집값 올해도 오를것” 68%  20210101      0.0
# ..    ...                                          ...       ...      ...
# 114  동아일보                           월드컵대교 개통… 통행하는 차량들  20210902      2.0
# 115  동아일보       인천 문학터널 내년 4월 무료 전환… 요금소 일대 활용 아이디어 공모  20210902      2.0
# 116  동아일보                     진주시 경남도농업기술원, 외곽 이전사업 순조  20210902      1.0
# 117  동아일보             “끔찍했던 화마의 기억 털어버리고 재입주할 날만 기다려요”  20210902      1.0
# 118  동아일보        ‘AI 수도’ 도약하는 광주시… 지역 기업들, 실리콘밸리 속속 진출  20210902      1.0
#
# [2485 rows x 4 columns]

# %%
df=pd.read_csv('title/tagged_data/data (5).csv',index_col = 0,encoding='utf-8-sig')
df
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27728/1767214669.py in <module>
# ----> 1 df=pd.read_csv('title/tagged_data/data (5).csv',index_col = 0,encoding='utf-8-sig')
#       2 df
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
for i in range(1,10):
    df=pd.read_csv(f'title/tagged_data/data ({i}).csv',index_col = 0,encoding='utf-8-sig')
    df.dropna(inplace=True)
    df.reset_index(inplace=True)
    df.drop(['index'],axis=1,inplace=True)
    뉴스리스트2.append(df)
df2=pd.concat([i for i in  뉴스리스트2])
df2
# Out:
#     press                                        title      date  emotion
# 0    경향신문          기침, 가래, 피로감 등 감염 후 한 달째…당신은 ‘롱 코비드’  20220401      0.0
# 1    경향신문                         가스요금 4월부터 월 860원 오른다  20220401      0.0
# 2    경향신문         거리 두기 ‘10명·밤 12시’ 유력…접종완료 입국자는 격리 면제  20220401      1.0
# 3    경향신문  성인용보다 용량 적은 화이자 접종…“독감주사 맞는다 생각, 별로 안 아팠어요”  20220401      2.0
# 4    경향신문                  하늘길 내달 ‘활짝’…여름엔 ‘예년 50%’ 회복  20220401      1.0
# ..    ...                                          ...       ...      ...
# 472  한국경제                    이번 급락장, 구원투수는 없다…냉철히 판단하라  20220129      0.0
# 473  한국경제               [클릭! 한경] 신혼집 살 돈 다 날려…개미들 '눈물'  20220129      0.0
# 474  한국경제                                감각을 잃은 푸틴의 오만  20220129      0.0
# 475  한국경제           [사설] 李 "박정희가 전라도 소외"…망국적 지역감정 부추기나  20220129      0.0
# 476  한국경제              [사설] 국민 들들 볶더니 확진 사실 숨긴 靑의 내로남불  20220129      0.0
#
# [2732 rows x 4 columns]

# %%
for i in range(1,12):
    df=pd.read_csv(f'title/tagged_data2/data ({i}).csv',index_col = 0,encoding='cp949')
    df.dropna(inplace=True)
    df.reset_index(inplace=True)
    df.drop(['index'],axis=1,inplace=True)
    뉴스리스트3.append(df)
df3=pd.concat([i for i in  뉴스리스트3])
df3
# Out:
#      press                                          title      date  emotion
# 0     경향신문                             “힘들어도 꾹 참다 응원에 울컥”  20200302        2
# 1     경향신문     루브르 문 닫고 미슐랭가이드 연기…코로나19 유럽 확산, 독·프 확진자 급증  20200302        0
# 2     경향신문                 ‘비례정당 선거연합’ 저울질…민주당이 잃을 명분과 실리  20200302        2
# 3     경향신문  미국서 첫 사망자 발생…“대구 여행 금지” 최고 수위 [‘코로나19’ 확산 비상]  20200302        0
# 4     경향신문    기업들, 출장·바이어 초청 취소 ‘해외영업 비상’ [‘코로나19’ 확산 비상]  20200302        0
# ..     ...                                            ...       ...      ...
# 298  한겨레신문         WHO “전세계 확산 결정적 시점”…캘리포니아 8400명 ‘관찰대상’  20200229        0
# 299  한겨레신문                 지역구 후보 안 낸다는 안철수, 통합당과 선거 연대하나  20200229        2
# 300  한겨레신문                [사설] 세금 감면 더해 ‘과감한 추경’으로 위기 대응을  20200229        2
# 301  한겨레신문            [사설] 대통령·여야 ‘코로나 회동’, 국가 역량 모으는 계기로  20200229        2
# 302  한겨레신문                [사설] 피해 최소화, 중증환자 분류·병상 협력에 달렸다  20200229        2
#
# [3133 rows x 4 columns]

# %%
df1=pd.read_csv('title/동아일보/동아일보_2021_01.csv',index_col = 0)


df1.dropna(inplace=True)

df1.reset_index(inplace=True)
df1.drop(['index'],axis=1,inplace=True)
df1
# Out:
#     press                                        title      date  emotion
# 0    동아일보   서울시장 선거 지지율… 안철수 24.2% 박영선 17.5% 나경원 14.5%  20210101      2.0
# 1    동아일보                       확진 900명 넘어서야… ‘뒷북 법무부’  20210101      2.0
# 2    동아일보                     文, 靑비서실장 유영민-민정수석 신현수 임명  20210101      2.0
# 3    동아일보  ‘피겨 여왕’ 김연아 “어려울수록 강해지는 대한민국…이번에도 딛고 일어서야죠”  20210101      2.0
# 4    동아일보       “文정부 부동산정책 잘못” 70%육박… “집값 올해도 오를것” 68%  20210101      0.0
# ..    ...                                          ...       ...      ...
# 306  동아일보        여야, ‘정인이법’ 8일 처리… 정부도 “아동학대 양형 상향 요청”  20210106      2.0
# 307  동아일보        “몸이 10개면 좋겠다” 코로나 최전선에 선 ‘메르스 전사’ 김현아  20210106      2.0
# 308  동아일보            한국에 백신비용 대납 요청했던 이란, 마무리 협상 직전 나포  20210106      0.0
# 309  동아일보             아덴만 작전 성공한 청해부대, 이번엔 군사대응 쉽지 않을듯  20210106      0.0
# 310  동아일보        美 “이란, 제재 흔들려는 의도”… 靑, NSC 열고 적극대응 선회  20210106      0.0
#
# [311 rows x 4 columns]

# %%
df4=pd.read_csv('testdata.csv',index_col = 0)
df4
# Out:
#     press                                              title      date  \
# 0    동아일보                              “공무원증 밥값 결제” 혁신賞 준 정부  20200101
# 1    동아일보                          “조국, 靑 최강욱 명의 아들 인턴증명 위조”  20200101
# 2    동아일보                                   동아일보 창간 100주년 기획  20200101
# 3    동아일보                  미래 100년 향해 펼쳐진 순백의 평원… 이야기를 채워주세요  20200101
# 4    동아일보                “PC에 다 있어” 인수인계 끝… 경험 축적은커녕 매번 원점으로  20200101
# ..    ...                                                ...       ...
# 643  경향신문                                이대로 보내기엔…너무 팔팔한 이대호  20220614
# 644  경향신문  ‘나 ML 출신’ 자존심만 앞세우면 ‘독’…열린 자세로 배우고 팀에 녹아들어야[선동...  20220614
# 645  경향신문                                  최혜진, LPGA 신인왕 보인다  20220614
# 646  경향신문               언니들 빠진 여자배구 ‘세자르호’…파리로 가는 길, 반전이 필요해  20220614
# 647  경향신문                       남녀 통합 골프대회 첫 여성 챔피언…男 부럽지 않네  20220614
#
#      emotion
# 0        1.0
# 1        0.0
# 2        2.0
# 3        2.0
# 4        0.0
# ..       ...
# ...

# %%
DF=pd.concat([df1 ,df2 ,df3, df4])
DF
# Out:
#     press                                              title      date  \
# 0    동아일보         서울시장 선거 지지율… 안철수 24.2% 박영선 17.5% 나경원 14.5%  20210101
# 1    동아일보                             확진 900명 넘어서야… ‘뒷북 법무부’  20210101
# 2    동아일보                           文, 靑비서실장 유영민-민정수석 신현수 임명  20210101
# 3    동아일보        ‘피겨 여왕’ 김연아 “어려울수록 강해지는 대한민국…이번에도 딛고 일어서야죠”  20210101
# 4    동아일보             “文정부 부동산정책 잘못” 70%육박… “집값 올해도 오를것” 68%  20210101
# ..    ...                                                ...       ...
# 643  경향신문                                이대로 보내기엔…너무 팔팔한 이대호  20220614
# 644  경향신문  ‘나 ML 출신’ 자존심만 앞세우면 ‘독’…열린 자세로 배우고 팀에 녹아들어야[선동...  20220614
# 645  경향신문                                  최혜진, LPGA 신인왕 보인다  20220614
# 646  경향신문               언니들 빠진 여자배구 ‘세자르호’…파리로 가는 길, 반전이 필요해  20220614
# 647  경향신문                       남녀 통합 골프대회 첫 여성 챔피언…男 부럽지 않네  20220614
#
#      emotion
# 0        2.0
# 1        2.0
# 2        2.0
# 3        2.0
# 4        0.0
# ..       ...
# ...

# %%
DF.to_csv('tagged_testdata.csv',encoding='utf-8-sig')
